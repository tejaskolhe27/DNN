# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
#
# ## Session 20c:
#
# ## LSTM - Weather data
#
#
# <img src='../../images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
# Lets import some libraries
import os

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from datetime import datetime, timedelta

from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, confusion_matrix

import tensorflow as tf

# %matplotlib inline
# Out:
# 2023-12-04 11:37:54.336297: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-04 11:37:54.387004: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-04 11:37:54.387042: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-04 11:37:54.388161: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-04 11:37:54.395775: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-04 11:37:55.440803: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2023-06-08 09:52:50.540007: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:52:50.620116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:52:50.620302: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# Strictly for tensorflow version 2.12
### To hide bugs throwing warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Some basic parameters

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results

EPOCHS = 500  # number of cycles to run

ALPHA = 0.1  # learning rate

TEST_SIZE = 0.2 # What fraction we want to keep for testing

BATCH_SIZE = 256

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (12,9),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }
CMAP = plt.cm.brg

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Helper Function

# %%
def fn_plot_label(train_df : pd.DataFrame , test_df : pd.DataFrame):
    
    plt.figure(figsize=(15,5))
    
    plt.subplot(1,2,1)
    
    ax = train_df

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %% [markdown]
# ## Load Weather Data
# Source: [Kaggle](https://www.kaggle.com/muthuj7/weather-dataset)

# %%
dataFilename = 'weatherHistory.csv'
data_df = pd.read_csv(os.path.join(inpDir, dataFilename))
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222  \
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)
# 0                  7.388889      0.89            14.1197  \
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)
# 0                   251.0          15.8263         0.0               1015.13  \
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
data_df.shape
# Out:
# (96453, 12)

# %%
data_df['datetime'] = pd.to_datetime(data_df['Formatted Date'], utc=True)

# %%
temp_df = data_df[['datetime', 'Temperature (C)']]
temp_df = temp_df.sort_values('datetime', axis=0, ascending=True)
temp_df = temp_df.reset_index(drop=True)
temp_df.head()
# Out:
#                    datetime  Temperature (C)
# 0 2005-12-31 23:00:00+00:00         0.577778
# 1 2006-01-01 00:00:00+00:00         1.161111
# 2 2006-01-01 01:00:00+00:00         1.666667
# 3 2006-01-01 02:00:00+00:00         1.711111
# 4 2006-01-01 03:00:00+00:00         1.183333

# %%
temp_df = temp_df.rename({'Temperature (C)': 'temp'}, axis=1)
temp_df.head()
# Out:
#                    datetime      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
# comment / uncomment following lines if you want part or full dataset

startDate = pd.to_datetime('2007-1-1', utc=True)
endDate = pd.to_datetime('2008-1-1', utc=True)
#temp_df = temp_df[(temp_df['datetime']  >= startDate) & (temp_df['datetime']  < endDate)]

# %%
temp_df.reset_index(drop=True, inplace = True)
temp_df.head()
# Out:
#                    datetime      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
temp_df.shape
# Out:
# (96453, 2)

# %% [markdown]
# ## Plotting samples

# %%
fig, ax = plt.subplots(figsize = (15,6))
temp_df.plot(x='datetime', y='temp', style=".", ax = ax);
ax.grid()

# %%
time_step = 24

# %%
y_idx = np.arange(time_step, temp_df.shape[0], time_step)
y_df = temp_df.iloc[y_idx]
y_df.head()
# Out:
#                      datetime      temp
# 24  2006-01-01 23:00:00+00:00  5.422222
# 48  2006-01-02 23:00:00+00:00  1.694444
# 72  2006-01-03 23:00:00+00:00  2.200000
# 96  2006-01-04 23:00:00+00:00  1.666667
# 120 2006-01-05 23:00:00+00:00  1.805556

# %%
y_df.shape, len(y_df)*time_step
# Out:
# ((4018, 2), 96432)

# %%
temp_df.shape
# Out:
# (96453, 2)

# %%
X_df = temp_df.iloc[range(len(y_df) * time_step)]

# %%
X_df['temp'].values.shape
# Out:
# (96432,)

# %%
X = np.reshape(X_df['temp'].values, (y_df.shape[0], time_step))
X.shape
# Out:
# (4018, 24)

# %%
X = X[:, :23]
X.shape
# Out:
# (4018, 23)

# %%
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# %%
split = int(y_df.shape[0] * (1-TEST_SIZE))
X_train = X[:split]
X_test = X[split:]
y_train = y_df['temp'].values[:split]
y_test = y_df['temp'].values[split:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3214, 23, 1), (804, 23, 1), (3214,), (804,))

# %%
scaler = StandardScaler()
# transform data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %%
h_units = 256

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.LSTM(h_units, activation ='tanh',
                               input_shape= (X_train.shape[1],X_train.shape[2]),
                               kernel_regularizer = 'l2'))

model.add(tf.keras.layers.Dense(128, 
                                activation ='tanh', 
                                kernel_regularizer = 'l2'))

model.add(tf.keras.layers.Dense(1, 
                                activation ='linear'))

model.compile(loss= 'mean_squared_error', optimizer = 'adam',
             metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dense (Dense)               (None, 128)               32896
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 297,217
# Trainable params: 297,217
# Non-trainable params: 0
# _________________________________________________________________
# 2023-06-08 09:55:48.958964: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:55:48.959429: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:55:48.959578: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:55:49.591971: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:55:49.592158: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:55:49.592290: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-08 09:55:49.592382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4069 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-06-08 09:55:49.733704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-08 09:55:49.734466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-08 09:55:49.735166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = model.fit ( X_train, y_train,
                     epochs = EPOCHS,
                     validation_data = (X_test, y_test),
                     batch_size = BATCH_SIZE,
                     verbose=2)
# Out:
# Epoch 1/500
# 2023-06-08 09:55:50.866492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-08 09:55:50.867367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-08 09:55:50.868373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-08 09:55:51.253972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-08 09:55:51.254817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-08 09:55:51.255724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-08 09:55:52.753249: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8901
# 2023-06-08 09:55:53.446840: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-08 09:55:53.463404: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7effc402d9c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-08 09:55:53.463425: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2023-06-08 09:55:53.466587: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-08 09:55:53.551001: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 13/13 - 3s - loss: 78.3136 - root_mean_squared_error: 8.7504 - val_loss: 30.4647 - val_root_mean_squared_error: 5.3581 - 3s/epoch - 265ms/step
# Epoch 2/500
# 13/13 - 0s - loss: 19.5249 - root_mean_squared_error: 4.2165 - val_loss: 15.6828 - val_root_mean_squared_error: 3.7350 - 84ms/epoch - 6ms/step
# Epoch 3/500
# 2023-06-08 09:55:54.086644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-08 09:55:54.087409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-08 09:55:54.088285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 - 0s - loss: 13.6807 - root_mean_squared_error: 3.4582 - val_loss: 9.1068 - val_root_mean_squared_error: 2.7203 - 85ms/epoch - 7ms/step
# Epoch 4/500
# 13/13 - 0s - loss: 9.2452 - root_mean_squared_error: 2.7475 - val_loss: 6.3177 - val_root_mean_squared_error: 2.1526 - 86ms/epoch - 7ms/step
# Epoch 5/500
# 13/13 - 0s - loss: 7.0681 - root_mean_squared_error: 2.3225 - val_loss: 5.4412 - val_root_mean_squared_error: 1.9441 - 79ms/epoch - 6ms/step
# Epoch 6/500
# 13/13 - 0s - loss: 6.1582 - root_mean_squared_error: 2.1229 - val_loss: 6.0307 - val_root_mean_squared_error: 2.0957 - 76ms/epoch - 6ms/step
# Epoch 7/500
# 13/13 - 0s - loss: 5.6291 - root_mean_squared_error: 2.0001 - val_loss: 5.2143 - val_root_mean_squared_error: 1.8967 - 73ms/epoch - 6ms/step
# Epoch 8/500
# 13/13 - 0s - loss: 4.8997 - root_mean_squared_error: 1.8147 - val_loss: 4.0526 - val_root_mean_squared_error: 1.5681 - 72ms/epoch - 6ms/step
# Epoch 9/500
# 13/13 - 0s - loss: 4.5952 - root_mean_squared_error: 1.7354 - val_loss: 3.7526 - val_root_mean_squared_error: 1.4772 - 72ms/epoch - 6ms/step
# Epoch 10/500
# 13/13 - 0s - loss: 4.2574 - root_mean_squared_error: 1.6426 - val_loss: 3.5099 - val_root_mean_squared_error: 1.4016 - 72ms/epoch - 6ms/step
# Epoch 11/500
# 13/13 - 0s - loss: 4.1012 - root_mean_squared_error: 1.6021 - val_loss: 3.4460 - val_root_mean_squared_error: 1.3876 - 71ms/epoch - 5ms/step
# Epoch 12/500
# 13/13 - 0s - loss: 3.9352 - root_mean_squared_error: 1.5577 - val_loss: 3.1039 - val_root_mean_squared_error: 1.2689 - 72ms/epoch - 6ms/step
# Epoch 13/500
# 13/13 - 0s - loss: 3.6250 - root_mean_squared_error: 1.4641 - val_loss: 3.0747 - val_root_mean_squared_error: 1.2683 - 72ms/epoch - 6ms/step
# Epoch 14/500
# 13/13 - 0s - loss: 3.4318 - root_mean_squared_error: 1.4067 - val_loss: 3.0981 - val_root_mean_squared_error: 1.2889 - 73ms/epoch - 6ms/step
# Epoch 15/500
# 13/13 - 0s - loss: 3.5013 - root_mean_squared_error: 1.4415 - val_loss: 2.8246 - val_root_mean_squared_error: 1.1905 - 72ms/epoch - 6ms/step
# Epoch 16/500
# 13/13 - 0s - loss: 3.3627 - root_mean_squared_error: 1.4026 - val_loss: 2.6751 - val_root_mean_squared_error: 1.1378 - 73ms/epoch - 6ms/step
# Epoch 17/500
# 13/13 - 0s - loss: 3.2297 - root_mean_squared_error: 1.3640 - val_loss: 3.3632 - val_root_mean_squared_error: 1.4173 - 72ms/epoch - 6ms/step
# Epoch 18/500
# 13/13 - 0s - loss: 3.1813 - root_mean_squared_error: 1.3560 - val_loss: 2.5849 - val_root_mean_squared_error: 1.1213 - 73ms/epoch - 6ms/step
# Epoch 19/500
# 13/13 - 0s - loss: 2.9925 - root_mean_squared_error: 1.2948 - val_loss: 2.6121 - val_root_mean_squared_error: 1.1447 - 72ms/epoch - 6ms/step
# Epoch 20/500
# 13/13 - 0s - loss: 2.8848 - root_mean_squared_error: 1.2627 - val_loss: 2.3962 - val_root_mean_squared_error: 1.0584 - 72ms/epoch - 6ms/step
# Epoch 21/500
# 13/13 - 0s - loss: 2.7888 - root_mean_squared_error: 1.2349 - val_loss: 2.3806 - val_root_mean_squared_error: 1.0639 - 72ms/epoch - 6ms/step
# Epoch 22/500
# 13/13 - 0s - loss: 2.8159 - root_mean_squared_error: 1.2562 - val_loss: 2.3446 - val_root_mean_squared_error: 1.0584 - 73ms/epoch - 6ms/step
# Epoch 23/500
# 13/13 - 0s - loss: 2.7151 - root_mean_squared_error: 1.2253 - val_loss: 2.5170 - val_root_mean_squared_error: 1.1474 - 73ms/epoch - 6ms/step
# Epoch 24/500
# 13/13 - 0s - loss: 2.5973 - root_mean_squared_error: 1.1864 - val_loss: 2.5835 - val_root_mean_squared_error: 1.1863 - 71ms/epoch - 5ms/step
# Epoch 25/500
# 13/13 - 0s - loss: 2.6088 - root_mean_squared_error: 1.2012 - val_loss: 2.3364 - val_root_mean_squared_error: 1.0881 - 72ms/epoch - 6ms/step
# Epoch 26/500
# 13/13 - 0s - loss: 2.6074 - root_mean_squared_error: 1.2105 - val_loss: 2.5679 - val_root_mean_squared_error: 1.1994 - 72ms/epoch - 6ms/step
# Epoch 27/500
# 13/13 - 0s - loss: 2.5800 - root_mean_squared_error: 1.2083 - val_loss: 2.1428 - val_root_mean_squared_error: 1.0174 - 74ms/epoch - 6ms/step
# Epoch 28/500
# 13/13 - 0s - loss: 2.4134 - root_mean_squared_error: 1.1468 - val_loss: 2.1904 - val_root_mean_squared_error: 1.0510 - 72ms/epoch - 6ms/step
# Epoch 29/500
# 13/13 - 0s - loss: 2.5034 - root_mean_squared_error: 1.1947 - val_loss: 2.0295 - val_root_mean_squared_error: 0.9831 - 72ms/epoch - 6ms/step
# Epoch 30/500
# 13/13 - 0s - loss: 2.3744 - root_mean_squared_error: 1.1490 - val_loss: 1.9731 - val_root_mean_squared_error: 0.9645 - 72ms/epoch - 6ms/step
# Epoch 31/500
# 13/13 - 0s - loss: 2.3646 - root_mean_squared_error: 1.1539 - val_loss: 2.0414 - val_root_mean_squared_error: 1.0094 - 72ms/epoch - 6ms/step
# Epoch 32/500
# 13/13 - 0s - loss: 2.4484 - root_mean_squared_error: 1.1979 - val_loss: 2.0287 - val_root_mean_squared_error: 1.0134 - 72ms/epoch - 6ms/step
# Epoch 33/500
# 13/13 - 0s - loss: 2.3878 - root_mean_squared_error: 1.1805 - val_loss: 2.0521 - val_root_mean_squared_error: 1.0331 - 73ms/epoch - 6ms/step
# Epoch 34/500
# 13/13 - 0s - loss: 2.2144 - root_mean_squared_error: 1.1128 - val_loss: 1.9589 - val_root_mean_squared_error: 0.9969 - 72ms/epoch - 6ms/step
# Epoch 35/500
# 13/13 - 0s - loss: 2.3540 - root_mean_squared_error: 1.1821 - val_loss: 1.9753 - val_root_mean_squared_error: 1.0145 - 74ms/epoch - 6ms/step
# Epoch 36/500
# 13/13 - 0s - loss: 2.2078 - root_mean_squared_error: 1.1271 - val_loss: 1.9442 - val_root_mean_squared_error: 1.0081 - 73ms/epoch - 6ms/step
# Epoch 37/500
# 13/13 - 0s - loss: 2.2274 - root_mean_squared_error: 1.1434 - val_loss: 1.7781 - val_root_mean_squared_error: 0.9317 - 72ms/epoch - 6ms/step
# Epoch 38/500
# 13/13 - 0s - loss: 2.1306 - root_mean_squared_error: 1.1081 - val_loss: 1.7819 - val_root_mean_squared_error: 0.9427 - 72ms/epoch - 6ms/step
# Epoch 39/500
# 13/13 - 0s - loss: 2.1085 - root_mean_squared_error: 1.1061 - val_loss: 1.7092 - val_root_mean_squared_error: 0.9135 - 72ms/epoch - 6ms/step
# Epoch 40/500
# 13/13 - 0s - loss: 2.0885 - root_mean_squared_error: 1.1053 - val_loss: 1.8144 - val_root_mean_squared_error: 0.9782 - 72ms/epoch - 6ms/step
# Epoch 41/500
# 13/13 - 0s - loss: 2.0790 - root_mean_squared_error: 1.1088 - val_loss: 2.1645 - val_root_mean_squared_error: 1.1507 - 72ms/epoch - 6ms/step
# Epoch 42/500
# 13/13 - 0s - loss: 2.1920 - root_mean_squared_error: 1.1657 - val_loss: 1.8318 - val_root_mean_squared_error: 1.0036 - 72ms/epoch - 6ms/step
# Epoch 43/500
# 13/13 - 0s - loss: 2.0178 - root_mean_squared_error: 1.0956 - val_loss: 1.6415 - val_root_mean_squared_error: 0.9122 - 72ms/epoch - 6ms/step
# Epoch 44/500
# 13/13 - 0s - loss: 1.9583 - root_mean_squared_error: 1.0750 - val_loss: 1.6862 - val_root_mean_squared_error: 0.9444 - 72ms/epoch - 6ms/step
# Epoch 45/500
# 13/13 - 0s - loss: 1.9792 - root_mean_squared_error: 1.0921 - val_loss: 1.6819 - val_root_mean_squared_error: 0.9514 - 74ms/epoch - 6ms/step
# Epoch 46/500
# 13/13 - 0s - loss: 1.9807 - root_mean_squared_error: 1.1000 - val_loss: 1.6883 - val_root_mean_squared_error: 0.9620 - 72ms/epoch - 6ms/step
# Epoch 47/500
# 13/13 - 0s - loss: 1.9176 - root_mean_squared_error: 1.0776 - val_loss: 1.5419 - val_root_mean_squared_error: 0.8910 - 72ms/epoch - 6ms/step
# Epoch 48/500
# 13/13 - 0s - loss: 1.9501 - root_mean_squared_error: 1.0993 - val_loss: 1.5513 - val_root_mean_squared_error: 0.9040 - 73ms/epoch - 6ms/step
# Epoch 49/500
# 13/13 - 0s - loss: 1.8965 - root_mean_squared_error: 1.0812 - val_loss: 1.6030 - val_root_mean_squared_error: 0.9398 - 73ms/epoch - 6ms/step
# Epoch 50/500
# 13/13 - 0s - loss: 1.9353 - root_mean_squared_error: 1.1051 - val_loss: 1.7107 - val_root_mean_squared_error: 1.0020 - 73ms/epoch - 6ms/step
# Epoch 51/500
# 13/13 - 0s - loss: 2.0479 - root_mean_squared_error: 1.1608 - val_loss: 1.9258 - val_root_mean_squared_error: 1.1099 - 72ms/epoch - 6ms/step
# Epoch 52/500
# 13/13 - 0s - loss: 1.9676 - root_mean_squared_error: 1.1310 - val_loss: 1.5585 - val_root_mean_squared_error: 0.9359 - 72ms/epoch - 6ms/step
# Epoch 53/500
# 13/13 - 0s - loss: 1.8371 - root_mean_squared_error: 1.0770 - val_loss: 1.4794 - val_root_mean_squared_error: 0.8996 - 73ms/epoch - 6ms/step
# Epoch 54/500
# 13/13 - 0s - loss: 1.8021 - root_mean_squared_error: 1.0664 - val_loss: 1.4380 - val_root_mean_squared_error: 0.8835 - 72ms/epoch - 6ms/step
# Epoch 55/500
# 13/13 - 0s - loss: 1.7623 - root_mean_squared_error: 1.0536 - val_loss: 1.4341 - val_root_mean_squared_error: 0.8879 - 74ms/epoch - 6ms/step
# Epoch 56/500
# 13/13 - 0s - loss: 1.7480 - root_mean_squared_error: 1.0528 - val_loss: 1.3939 - val_root_mean_squared_error: 0.8724 - 74ms/epoch - 6ms/step
# Epoch 57/500
# 13/13 - 0s - loss: 1.7970 - root_mean_squared_error: 1.0816 - val_loss: 1.5092 - val_root_mean_squared_error: 0.9428 - 73ms/epoch - 6ms/step
# Epoch 58/500
# 13/13 - 0s - loss: 1.7732 - root_mean_squared_error: 1.0761 - val_loss: 1.3773 - val_root_mean_squared_error: 0.8766 - 74ms/epoch - 6ms/step
# Epoch 59/500
# 13/13 - 0s - loss: 1.7134 - root_mean_squared_error: 1.0532 - val_loss: 1.3909 - val_root_mean_squared_error: 0.8904 - 74ms/epoch - 6ms/step
# Epoch 60/500
# 13/13 - 0s - loss: 1.7005 - root_mean_squared_error: 1.0523 - val_loss: 1.4137 - val_root_mean_squared_error: 0.9093 - 73ms/epoch - 6ms/step
# Epoch 61/500
# 13/13 - 0s - loss: 1.7358 - root_mean_squared_error: 1.0741 - val_loss: 1.4604 - val_root_mean_squared_error: 0.9404 - 74ms/epoch - 6ms/step
# Epoch 62/500
# 13/13 - 0s - loss: 1.7428 - root_mean_squared_error: 1.0822 - val_loss: 1.4396 - val_root_mean_squared_error: 0.9347 - 72ms/epoch - 6ms/step
# Epoch 63/500
# 13/13 - 0s - loss: 1.6749 - root_mean_squared_error: 1.0552 - val_loss: 1.5270 - val_root_mean_squared_error: 0.9849 - 73ms/epoch - 6ms/step
# Epoch 64/500
# 13/13 - 0s - loss: 1.6608 - root_mean_squared_error: 1.0528 - val_loss: 1.4011 - val_root_mean_squared_error: 0.9247 - 76ms/epoch - 6ms/step
# Epoch 65/500
# 13/13 - 0s - loss: 1.6611 - root_mean_squared_error: 1.0578 - val_loss: 1.2923 - val_root_mean_squared_error: 0.8694 - 80ms/epoch - 6ms/step
# Epoch 66/500
# 13/13 - 0s - loss: 1.6670 - root_mean_squared_error: 1.0652 - val_loss: 1.2780 - val_root_mean_squared_error: 0.8666 - 76ms/epoch - 6ms/step
# Epoch 67/500
# 13/13 - 0s - loss: 1.6407 - root_mean_squared_error: 1.0570 - val_loss: 1.2829 - val_root_mean_squared_error: 0.8744 - 77ms/epoch - 6ms/step
# Epoch 68/500
# 13/13 - 0s - loss: 1.6095 - root_mean_squared_error: 1.0465 - val_loss: 1.2515 - val_root_mean_squared_error: 0.8615 - 77ms/epoch - 6ms/step
# Epoch 69/500
# 13/13 - 0s - loss: 1.5899 - root_mean_squared_error: 1.0414 - val_loss: 1.3518 - val_root_mean_squared_error: 0.9232 - 79ms/epoch - 6ms/step
# Epoch 70/500
# 13/13 - 0s - loss: 1.5887 - root_mean_squared_error: 1.0452 - val_loss: 1.2695 - val_root_mean_squared_error: 0.8819 - 78ms/epoch - 6ms/step
# Epoch 71/500
# 13/13 - 0s - loss: 1.5678 - root_mean_squared_error: 1.0394 - val_loss: 1.2150 - val_root_mean_squared_error: 0.8556 - 78ms/epoch - 6ms/step
# Epoch 72/500
# 13/13 - 0s - loss: 1.5495 - root_mean_squared_error: 1.0346 - val_loss: 1.2399 - val_root_mean_squared_error: 0.8752 - 72ms/epoch - 6ms/step
# Epoch 73/500
# 13/13 - 0s - loss: 1.5573 - root_mean_squared_error: 1.0425 - val_loss: 1.2161 - val_root_mean_squared_error: 0.8661 - 72ms/epoch - 6ms/step
# Epoch 74/500
# 13/13 - 0s - loss: 1.5413 - root_mean_squared_error: 1.0388 - val_loss: 1.2251 - val_root_mean_squared_error: 0.8762 - 72ms/epoch - 6ms/step
# Epoch 75/500
# 13/13 - 0s - loss: 1.5906 - root_mean_squared_error: 1.0659 - val_loss: 1.3874 - val_root_mean_squared_error: 0.9680 - 71ms/epoch - 5ms/step
# Epoch 76/500
# 13/13 - 0s - loss: 1.5288 - root_mean_squared_error: 1.0398 - val_loss: 1.1694 - val_root_mean_squared_error: 0.8520 - 73ms/epoch - 6ms/step
# Epoch 77/500
# 13/13 - 0s - loss: 1.4890 - root_mean_squared_error: 1.0240 - val_loss: 1.3094 - val_root_mean_squared_error: 0.9342 - 76ms/epoch - 6ms/step
# Epoch 78/500
# 13/13 - 0s - loss: 1.4963 - root_mean_squared_error: 1.0313 - val_loss: 1.2388 - val_root_mean_squared_error: 0.9000 - 76ms/epoch - 6ms/step
# Epoch 79/500
# 13/13 - 0s - loss: 1.5501 - root_mean_squared_error: 1.0607 - val_loss: 1.1681 - val_root_mean_squared_error: 0.8642 - 76ms/epoch - 6ms/step
# Epoch 80/500
# 13/13 - 0s - loss: 1.5121 - root_mean_squared_error: 1.0459 - val_loss: 1.1933 - val_root_mean_squared_error: 0.8828 - 76ms/epoch - 6ms/step
# Epoch 81/500
# 13/13 - 0s - loss: 1.5178 - root_mean_squared_error: 1.0514 - val_loss: 1.1359 - val_root_mean_squared_error: 0.8522 - 76ms/epoch - 6ms/step
# Epoch 82/500
# 13/13 - 0s - loss: 1.4667 - root_mean_squared_error: 1.0299 - val_loss: 1.1246 - val_root_mean_squared_error: 0.8494 - 73ms/epoch - 6ms/step
# Epoch 83/500
# 13/13 - 0s - loss: 1.4362 - root_mean_squared_error: 1.0180 - val_loss: 1.2979 - val_root_mean_squared_error: 0.9493 - 72ms/epoch - 6ms/step
# Epoch 84/500
# 13/13 - 0s - loss: 1.4580 - root_mean_squared_error: 1.0318 - val_loss: 1.1874 - val_root_mean_squared_error: 0.8936 - 72ms/epoch - 6ms/step
# Epoch 85/500
# 13/13 - 0s - loss: 1.4753 - root_mean_squared_error: 1.0436 - val_loss: 1.1275 - val_root_mean_squared_error: 0.8620 - 73ms/epoch - 6ms/step
# Epoch 86/500
# 13/13 - 0s - loss: 1.4703 - root_mean_squared_error: 1.0438 - val_loss: 1.2533 - val_root_mean_squared_error: 0.9356 - 72ms/epoch - 6ms/step
# Epoch 87/500
# 13/13 - 0s - loss: 1.4848 - root_mean_squared_error: 1.0532 - val_loss: 1.0910 - val_root_mean_squared_error: 0.8476 - 72ms/epoch - 6ms/step
# Epoch 88/500
# 13/13 - 0s - loss: 1.4216 - root_mean_squared_error: 1.0256 - val_loss: 1.1747 - val_root_mean_squared_error: 0.8990 - 71ms/epoch - 5ms/step
# Epoch 89/500
# 13/13 - 0s - loss: 1.4307 - root_mean_squared_error: 1.0326 - val_loss: 1.0904 - val_root_mean_squared_error: 0.8535 - 73ms/epoch - 6ms/step
# Epoch 90/500
# 13/13 - 0s - loss: 1.4448 - root_mean_squared_error: 1.0421 - val_loss: 1.0636 - val_root_mean_squared_error: 0.8410 - 71ms/epoch - 5ms/step
# Epoch 91/500
# 13/13 - 0s - loss: 1.3933 - root_mean_squared_error: 1.0195 - val_loss: 1.0809 - val_root_mean_squared_error: 0.8545 - 72ms/epoch - 6ms/step
# Epoch 92/500
# 13/13 - 0s - loss: 1.4863 - root_mean_squared_error: 1.0666 - val_loss: 1.4045 - val_root_mean_squared_error: 1.0284 - 71ms/epoch - 5ms/step
# Epoch 93/500
# 13/13 - 0s - loss: 1.4404 - root_mean_squared_error: 1.0470 - val_loss: 1.0500 - val_root_mean_squared_error: 0.8419 - 72ms/epoch - 6ms/step
# Epoch 94/500
# 13/13 - 0s - loss: 1.3776 - root_mean_squared_error: 1.0189 - val_loss: 1.0494 - val_root_mean_squared_error: 0.8438 - 72ms/epoch - 6ms/step
# Epoch 95/500
# 13/13 - 0s - loss: 1.3892 - root_mean_squared_error: 1.0269 - val_loss: 1.2977 - val_root_mean_squared_error: 0.9827 - 71ms/epoch - 5ms/step
# Epoch 96/500
# 13/13 - 0s - loss: 1.4230 - root_mean_squared_error: 1.0456 - val_loss: 1.0904 - val_root_mean_squared_error: 0.8745 - 71ms/epoch - 5ms/step
# Epoch 97/500
# 13/13 - 0s - loss: 1.3989 - root_mean_squared_error: 1.0362 - val_loss: 1.2514 - val_root_mean_squared_error: 0.9627 - 71ms/epoch - 5ms/step
# Epoch 98/500
# 13/13 - 0s - loss: 1.3922 - root_mean_squared_error: 1.0346 - val_loss: 1.1219 - val_root_mean_squared_error: 0.8963 - 72ms/epoch - 6ms/step
# Epoch 99/500
# 13/13 - 0s - loss: 1.4266 - root_mean_squared_error: 1.0531 - val_loss: 1.1298 - val_root_mean_squared_error: 0.9024 - 73ms/epoch - 6ms/step
# Epoch 100/500
# 13/13 - 0s - loss: 1.4340 - root_mean_squared_error: 1.0584 - val_loss: 1.0209 - val_root_mean_squared_error: 0.8421 - 73ms/epoch - 6ms/step
# Epoch 101/500
# 13/13 - 0s - loss: 1.4063 - root_mean_squared_error: 1.0472 - val_loss: 1.0324 - val_root_mean_squared_error: 0.8514 - 73ms/epoch - 6ms/step
# Epoch 102/500
# 13/13 - 0s - loss: 1.3537 - root_mean_squared_error: 1.0234 - val_loss: 1.0106 - val_root_mean_squared_error: 0.8401 - 72ms/epoch - 6ms/step
# Epoch 103/500
# 13/13 - 0s - loss: 1.3252 - root_mean_squared_error: 1.0111 - val_loss: 0.9982 - val_root_mean_squared_error: 0.8348 - 72ms/epoch - 6ms/step
# Epoch 104/500
# 13/13 - 0s - loss: 1.3260 - root_mean_squared_error: 1.0135 - val_loss: 1.0023 - val_root_mean_squared_error: 0.8395 - 73ms/epoch - 6ms/step
# Epoch 105/500
# 13/13 - 0s - loss: 1.3141 - root_mean_squared_error: 1.0099 - val_loss: 1.0355 - val_root_mean_squared_error: 0.8631 - 78ms/epoch - 6ms/step
# Epoch 106/500
# 13/13 - 0s - loss: 1.3163 - root_mean_squared_error: 1.0129 - val_loss: 0.9806 - val_root_mean_squared_error: 0.8320 - 79ms/epoch - 6ms/step
# Epoch 107/500
# 13/13 - 0s - loss: 1.3010 - root_mean_squared_error: 1.0073 - val_loss: 0.9638 - val_root_mean_squared_error: 0.8244 - 73ms/epoch - 6ms/step
# Epoch 108/500
# 13/13 - 0s - loss: 1.4050 - root_mean_squared_error: 1.0597 - val_loss: 1.0586 - val_root_mean_squared_error: 0.8824 - 72ms/epoch - 6ms/step
# Epoch 109/500
# 13/13 - 0s - loss: 1.3840 - root_mean_squared_error: 1.0513 - val_loss: 0.9762 - val_root_mean_squared_error: 0.8356 - 72ms/epoch - 6ms/step
# Epoch 110/500
# 13/13 - 0s - loss: 1.2945 - root_mean_squared_error: 1.0090 - val_loss: 0.9543 - val_root_mean_squared_error: 0.8243 - 73ms/epoch - 6ms/step
# Epoch 111/500
# 13/13 - 0s - loss: 1.3023 - root_mean_squared_error: 1.0143 - val_loss: 1.0040 - val_root_mean_squared_error: 0.8561 - 73ms/epoch - 6ms/step
# Epoch 112/500
# 13/13 - 0s - loss: 1.2712 - root_mean_squared_error: 1.0006 - val_loss: 0.9610 - val_root_mean_squared_error: 0.8325 - 71ms/epoch - 5ms/step
# Epoch 113/500
# 13/13 - 0s - loss: 1.2769 - root_mean_squared_error: 1.0055 - val_loss: 0.9486 - val_root_mean_squared_error: 0.8273 - 72ms/epoch - 6ms/step
# Epoch 114/500
# 13/13 - 0s - loss: 1.2950 - root_mean_squared_error: 1.0162 - val_loss: 1.1005 - val_root_mean_squared_error: 0.9167 - 73ms/epoch - 6ms/step
# Epoch 115/500
# 13/13 - 0s - loss: 1.3741 - root_mean_squared_error: 1.0562 - val_loss: 0.9547 - val_root_mean_squared_error: 0.8349 - 72ms/epoch - 6ms/step
# Epoch 116/500
# 13/13 - 0s - loss: 1.3106 - root_mean_squared_error: 1.0266 - val_loss: 0.9295 - val_root_mean_squared_error: 0.8209 - 72ms/epoch - 6ms/step
# Epoch 117/500
# 13/13 - 0s - loss: 1.3057 - root_mean_squared_error: 1.0253 - val_loss: 0.9983 - val_root_mean_squared_error: 0.8644 - 72ms/epoch - 6ms/step
# Epoch 118/500
# 13/13 - 0s - loss: 1.2443 - root_mean_squared_error: 0.9964 - val_loss: 0.9318 - val_root_mean_squared_error: 0.8257 - 71ms/epoch - 5ms/step
# Epoch 119/500
# 13/13 - 0s - loss: 1.2572 - root_mean_squared_error: 1.0043 - val_loss: 0.9406 - val_root_mean_squared_error: 0.8327 - 71ms/epoch - 5ms/step
# Epoch 120/500
# 13/13 - 0s - loss: 1.2503 - root_mean_squared_error: 1.0023 - val_loss: 0.9616 - val_root_mean_squared_error: 0.8467 - 71ms/epoch - 5ms/step
# Epoch 121/500
# 13/13 - 0s - loss: 1.2558 - root_mean_squared_error: 1.0068 - val_loss: 0.9474 - val_root_mean_squared_error: 0.8404 - 72ms/epoch - 6ms/step
# Epoch 122/500
# 13/13 - 0s - loss: 1.2805 - root_mean_squared_error: 1.0204 - val_loss: 0.9985 - val_root_mean_squared_error: 0.8721 - 71ms/epoch - 5ms/step
# Epoch 123/500
# 13/13 - 0s - loss: 1.2789 - root_mean_squared_error: 1.0210 - val_loss: 0.9314 - val_root_mean_squared_error: 0.8349 - 74ms/epoch - 6ms/step
# Epoch 124/500
# 13/13 - 0s - loss: 1.2598 - root_mean_squared_error: 1.0132 - val_loss: 0.9320 - val_root_mean_squared_error: 0.8364 - 75ms/epoch - 6ms/step
# Epoch 125/500
# 13/13 - 0s - loss: 1.2599 - root_mean_squared_error: 1.0141 - val_loss: 1.0541 - val_root_mean_squared_error: 0.9074 - 77ms/epoch - 6ms/step
# Epoch 126/500
# 13/13 - 0s - loss: 1.2296 - root_mean_squared_error: 1.0001 - val_loss: 0.8992 - val_root_mean_squared_error: 0.8195 - 76ms/epoch - 6ms/step
# Epoch 127/500
# 13/13 - 0s - loss: 1.2624 - root_mean_squared_error: 1.0178 - val_loss: 0.9234 - val_root_mean_squared_error: 0.8355 - 76ms/epoch - 6ms/step
# Epoch 128/500
# 13/13 - 0s - loss: 1.2412 - root_mean_squared_error: 1.0085 - val_loss: 0.9619 - val_root_mean_squared_error: 0.8596 - 76ms/epoch - 6ms/step
# Epoch 129/500
# 13/13 - 0s - loss: 1.2027 - root_mean_squared_error: 0.9904 - val_loss: 1.0104 - val_root_mean_squared_error: 0.8889 - 76ms/epoch - 6ms/step
# Epoch 130/500
# 13/13 - 0s - loss: 1.2281 - root_mean_squared_error: 1.0043 - val_loss: 0.9138 - val_root_mean_squared_error: 0.8339 - 74ms/epoch - 6ms/step
# Epoch 131/500
# 13/13 - 0s - loss: 1.2278 - root_mean_squared_error: 1.0056 - val_loss: 0.9288 - val_root_mean_squared_error: 0.8442 - 72ms/epoch - 6ms/step
# Epoch 132/500
# 13/13 - 0s - loss: 1.2315 - root_mean_squared_error: 1.0084 - val_loss: 0.9881 - val_root_mean_squared_error: 0.8808 - 72ms/epoch - 6ms/step
# Epoch 133/500
# 13/13 - 0s - loss: 1.2233 - root_mean_squared_error: 1.0054 - val_loss: 0.9227 - val_root_mean_squared_error: 0.8431 - 74ms/epoch - 6ms/step
# Epoch 134/500
# 13/13 - 0s - loss: 1.2389 - root_mean_squared_error: 1.0141 - val_loss: 0.8794 - val_root_mean_squared_error: 0.8184 - 72ms/epoch - 6ms/step
# Epoch 135/500
# 13/13 - 0s - loss: 1.1989 - root_mean_squared_error: 0.9952 - val_loss: 0.9012 - val_root_mean_squared_error: 0.8329 - 73ms/epoch - 6ms/step
# Epoch 136/500
# 13/13 - 0s - loss: 1.2059 - root_mean_squared_error: 0.9998 - val_loss: 0.8824 - val_root_mean_squared_error: 0.8230 - 73ms/epoch - 6ms/step
# Epoch 137/500
# 13/13 - 0s - loss: 1.3057 - root_mean_squared_error: 1.0495 - val_loss: 0.9997 - val_root_mean_squared_error: 0.8923 - 72ms/epoch - 6ms/step
# Epoch 138/500
# 13/13 - 0s - loss: 1.2445 - root_mean_squared_error: 1.0207 - val_loss: 1.0891 - val_root_mean_squared_error: 0.9409 - 72ms/epoch - 6ms/step
# Epoch 139/500
# 13/13 - 0s - loss: 1.2530 - root_mean_squared_error: 1.0252 - val_loss: 0.9201 - val_root_mean_squared_error: 0.8482 - 72ms/epoch - 6ms/step
# Epoch 140/500
# 13/13 - 0s - loss: 1.1952 - root_mean_squared_error: 0.9973 - val_loss: 0.8640 - val_root_mean_squared_error: 0.8151 - 75ms/epoch - 6ms/step
# Epoch 141/500
# 13/13 - 0s - loss: 1.1727 - root_mean_squared_error: 0.9869 - val_loss: 0.8623 - val_root_mean_squared_error: 0.8152 - 72ms/epoch - 6ms/step
# Epoch 142/500
# 13/13 - 0s - loss: 1.2011 - root_mean_squared_error: 1.0024 - val_loss: 0.9505 - val_root_mean_squared_error: 0.8691 - 72ms/epoch - 6ms/step
# Epoch 143/500
# 13/13 - 0s - loss: 1.1954 - root_mean_squared_error: 1.0006 - val_loss: 0.8868 - val_root_mean_squared_error: 0.8328 - 71ms/epoch - 5ms/step
# Epoch 144/500
# 13/13 - 0s - loss: 1.1796 - root_mean_squared_error: 0.9938 - val_loss: 0.9173 - val_root_mean_squared_error: 0.8526 - 71ms/epoch - 5ms/step
# Epoch 145/500
# 13/13 - 0s - loss: 1.1816 - root_mean_squared_error: 0.9956 - val_loss: 0.8726 - val_root_mean_squared_error: 0.8273 - 73ms/epoch - 6ms/step
# Epoch 146/500
# 13/13 - 0s - loss: 1.1668 - root_mean_squared_error: 0.9893 - val_loss: 0.9248 - val_root_mean_squared_error: 0.8591 - 72ms/epoch - 6ms/step
# Epoch 147/500
# 13/13 - 0s - loss: 1.1861 - root_mean_squared_error: 0.9998 - val_loss: 0.8811 - val_root_mean_squared_error: 0.8345 - 72ms/epoch - 6ms/step
# Epoch 148/500
# 13/13 - 0s - loss: 1.2021 - root_mean_squared_error: 1.0091 - val_loss: 0.8861 - val_root_mean_squared_error: 0.8378 - 73ms/epoch - 6ms/step
# Epoch 149/500
# 13/13 - 0s - loss: 1.2315 - root_mean_squared_error: 1.0241 - val_loss: 0.8714 - val_root_mean_squared_error: 0.8307 - 73ms/epoch - 6ms/step
# Epoch 150/500
# 13/13 - 0s - loss: 1.2136 - root_mean_squared_error: 1.0162 - val_loss: 1.0413 - val_root_mean_squared_error: 0.9271 - 71ms/epoch - 5ms/step
# Epoch 151/500
# 13/13 - 0s - loss: 1.1655 - root_mean_squared_error: 0.9925 - val_loss: 0.9277 - val_root_mean_squared_error: 0.8650 - 73ms/epoch - 6ms/step
# Epoch 152/500
# 13/13 - 0s - loss: 1.1761 - root_mean_squared_error: 0.9988 - val_loss: 0.9045 - val_root_mean_squared_error: 0.8524 - 72ms/epoch - 6ms/step
# Epoch 153/500
# 13/13 - 0s - loss: 1.1746 - root_mean_squared_error: 0.9988 - val_loss: 0.8419 - val_root_mean_squared_error: 0.8157 - 72ms/epoch - 6ms/step
# Epoch 154/500
# 13/13 - 0s - loss: 1.1849 - root_mean_squared_error: 1.0046 - val_loss: 0.8884 - val_root_mean_squared_error: 0.8447 - 72ms/epoch - 6ms/step
# Epoch 155/500
# 13/13 - 0s - loss: 1.2060 - root_mean_squared_error: 1.0159 - val_loss: 0.8508 - val_root_mean_squared_error: 0.8231 - 73ms/epoch - 6ms/step
# Epoch 156/500
# 13/13 - 0s - loss: 1.1446 - root_mean_squared_error: 0.9857 - val_loss: 0.8349 - val_root_mean_squared_error: 0.8140 - 71ms/epoch - 5ms/step
# Epoch 157/500
# 13/13 - 0s - loss: 1.1418 - root_mean_squared_error: 0.9850 - val_loss: 0.8533 - val_root_mean_squared_error: 0.8265 - 72ms/epoch - 6ms/step
# Epoch 158/500
# 13/13 - 0s - loss: 1.1406 - root_mean_squared_error: 0.9857 - val_loss: 0.8495 - val_root_mean_squared_error: 0.8253 - 71ms/epoch - 5ms/step
# Epoch 159/500
# 13/13 - 0s - loss: 1.1499 - root_mean_squared_error: 0.9911 - val_loss: 0.8902 - val_root_mean_squared_error: 0.8505 - 72ms/epoch - 6ms/step
# Epoch 160/500
# 13/13 - 0s - loss: 1.1471 - root_mean_squared_error: 0.9904 - val_loss: 0.8431 - val_root_mean_squared_error: 0.8236 - 70ms/epoch - 5ms/step
# Epoch 161/500
# 13/13 - 0s - loss: 1.1691 - root_mean_squared_error: 1.0022 - val_loss: 0.8487 - val_root_mean_squared_error: 0.8278 - 71ms/epoch - 5ms/step
# Epoch 162/500
# 13/13 - 0s - loss: 1.1729 - root_mean_squared_error: 1.0050 - val_loss: 0.8632 - val_root_mean_squared_error: 0.8364 - 71ms/epoch - 5ms/step
# Epoch 163/500
# 13/13 - 0s - loss: 1.1752 - root_mean_squared_error: 1.0062 - val_loss: 0.8321 - val_root_mean_squared_error: 0.8187 - 72ms/epoch - 6ms/step
# Epoch 164/500
# 13/13 - 0s - loss: 1.1418 - root_mean_squared_error: 0.9900 - val_loss: 0.8334 - val_root_mean_squared_error: 0.8198 - 72ms/epoch - 6ms/step
# Epoch 165/500
# 13/13 - 0s - loss: 1.1419 - root_mean_squared_error: 0.9905 - val_loss: 0.8497 - val_root_mean_squared_error: 0.8304 - 72ms/epoch - 6ms/step
# Epoch 166/500
# 13/13 - 0s - loss: 1.1277 - root_mean_squared_error: 0.9841 - val_loss: 0.8650 - val_root_mean_squared_error: 0.8407 - 72ms/epoch - 6ms/step
# Epoch 167/500
# 13/13 - 0s - loss: 1.1246 - root_mean_squared_error: 0.9835 - val_loss: 0.8309 - val_root_mean_squared_error: 0.8215 - 71ms/epoch - 5ms/step
# Epoch 168/500
# 13/13 - 0s - loss: 1.1240 - root_mean_squared_error: 0.9837 - val_loss: 0.8585 - val_root_mean_squared_error: 0.8386 - 72ms/epoch - 6ms/step
# Epoch 169/500
# 13/13 - 0s - loss: 1.1185 - root_mean_squared_error: 0.9820 - val_loss: 0.8602 - val_root_mean_squared_error: 0.8406 - 71ms/epoch - 5ms/step
# Epoch 170/500
# 13/13 - 0s - loss: 1.1269 - root_mean_squared_error: 0.9867 - val_loss: 0.8596 - val_root_mean_squared_error: 0.8410 - 74ms/epoch - 6ms/step
# Epoch 171/500
# 13/13 - 0s - loss: 1.1588 - root_mean_squared_error: 1.0036 - val_loss: 0.8588 - val_root_mean_squared_error: 0.8409 - 77ms/epoch - 6ms/step
# Epoch 172/500
# 13/13 - 0s - loss: 1.1814 - root_mean_squared_error: 1.0150 - val_loss: 0.9276 - val_root_mean_squared_error: 0.8823 - 76ms/epoch - 6ms/step
# Epoch 173/500
# 13/13 - 0s - loss: 1.1489 - root_mean_squared_error: 0.9992 - val_loss: 0.8280 - val_root_mean_squared_error: 0.8233 - 76ms/epoch - 6ms/step
# Epoch 174/500
# 13/13 - 0s - loss: 1.1153 - root_mean_squared_error: 0.9823 - val_loss: 0.8294 - val_root_mean_squared_error: 0.8243 - 77ms/epoch - 6ms/step
# Epoch 175/500
# 13/13 - 0s - loss: 1.1185 - root_mean_squared_error: 0.9845 - val_loss: 0.8961 - val_root_mean_squared_error: 0.8657 - 76ms/epoch - 6ms/step
# Epoch 176/500
# 13/13 - 0s - loss: 1.1484 - root_mean_squared_error: 1.0002 - val_loss: 0.9163 - val_root_mean_squared_error: 0.8773 - 77ms/epoch - 6ms/step
# Epoch 177/500
# 13/13 - 0s - loss: 1.1600 - root_mean_squared_error: 1.0068 - val_loss: 0.8719 - val_root_mean_squared_error: 0.8517 - 75ms/epoch - 6ms/step
# Epoch 178/500
# 13/13 - 0s - loss: 1.1176 - root_mean_squared_error: 0.9861 - val_loss: 0.8161 - val_root_mean_squared_error: 0.8193 - 72ms/epoch - 6ms/step
# Epoch 179/500
# 13/13 - 0s - loss: 1.1335 - root_mean_squared_error: 0.9940 - val_loss: 0.8938 - val_root_mean_squared_error: 0.8652 - 74ms/epoch - 6ms/step
# Epoch 180/500
# 13/13 - 0s - loss: 1.1623 - root_mean_squared_error: 1.0093 - val_loss: 0.9192 - val_root_mean_squared_error: 0.8810 - 71ms/epoch - 5ms/step
# Epoch 181/500
# 13/13 - 0s - loss: 1.1670 - root_mean_squared_error: 1.0120 - val_loss: 0.8420 - val_root_mean_squared_error: 0.8366 - 72ms/epoch - 6ms/step
# Epoch 182/500
# 13/13 - 0s - loss: 1.1369 - root_mean_squared_error: 0.9973 - val_loss: 0.9402 - val_root_mean_squared_error: 0.8925 - 72ms/epoch - 6ms/step
# Epoch 183/500
# 13/13 - 0s - loss: 1.1372 - root_mean_squared_error: 0.9976 - val_loss: 0.9641 - val_root_mean_squared_error: 0.9076 - 72ms/epoch - 6ms/step
# Epoch 184/500
# 13/13 - 0s - loss: 1.2355 - root_mean_squared_error: 1.0460 - val_loss: 0.8354 - val_root_mean_squared_error: 0.8325 - 72ms/epoch - 6ms/step
# Epoch 185/500
# 13/13 - 0s - loss: 1.2350 - root_mean_squared_error: 1.0454 - val_loss: 0.8317 - val_root_mean_squared_error: 0.8301 - 72ms/epoch - 6ms/step
# Epoch 186/500
# 13/13 - 0s - loss: 1.1623 - root_mean_squared_error: 1.0100 - val_loss: 0.8664 - val_root_mean_squared_error: 0.8507 - 72ms/epoch - 6ms/step
# Epoch 187/500
# 13/13 - 0s - loss: 1.1350 - root_mean_squared_error: 0.9968 - val_loss: 0.8176 - val_root_mean_squared_error: 0.8225 - 72ms/epoch - 6ms/step
# Epoch 188/500
# 13/13 - 0s - loss: 1.1136 - root_mean_squared_error: 0.9864 - val_loss: 0.8129 - val_root_mean_squared_error: 0.8199 - 72ms/epoch - 6ms/step
# Epoch 189/500
# 13/13 - 0s - loss: 1.1136 - root_mean_squared_error: 0.9866 - val_loss: 0.8280 - val_root_mean_squared_error: 0.8295 - 72ms/epoch - 6ms/step
# Epoch 190/500
# 13/13 - 0s - loss: 1.1274 - root_mean_squared_error: 0.9943 - val_loss: 0.8746 - val_root_mean_squared_error: 0.8585 - 73ms/epoch - 6ms/step
# Epoch 191/500
# 13/13 - 0s - loss: 1.1331 - root_mean_squared_error: 0.9978 - val_loss: 0.8795 - val_root_mean_squared_error: 0.8608 - 75ms/epoch - 6ms/step
# Epoch 192/500
# 13/13 - 0s - loss: 1.1134 - root_mean_squared_error: 0.9881 - val_loss: 0.8324 - val_root_mean_squared_error: 0.8348 - 74ms/epoch - 6ms/step
# Epoch 193/500
# 13/13 - 0s - loss: 1.1232 - root_mean_squared_error: 0.9934 - val_loss: 0.9787 - val_root_mean_squared_error: 0.9175 - 76ms/epoch - 6ms/step
# Epoch 194/500
# 13/13 - 0s - loss: 1.1342 - root_mean_squared_error: 0.9992 - val_loss: 0.9878 - val_root_mean_squared_error: 0.9247 - 75ms/epoch - 6ms/step
# Epoch 195/500
# 13/13 - 0s - loss: 1.1782 - root_mean_squared_error: 1.0216 - val_loss: 1.0429 - val_root_mean_squared_error: 0.9521 - 75ms/epoch - 6ms/step
# Epoch 196/500
# 13/13 - 0s - loss: 1.1567 - root_mean_squared_error: 1.0107 - val_loss: 0.8728 - val_root_mean_squared_error: 0.8600 - 77ms/epoch - 6ms/step
# Epoch 197/500
# 13/13 - 0s - loss: 1.0916 - root_mean_squared_error: 0.9786 - val_loss: 0.8281 - val_root_mean_squared_error: 0.8326 - 74ms/epoch - 6ms/step
# Epoch 198/500
# 13/13 - 0s - loss: 1.1026 - root_mean_squared_error: 0.9843 - val_loss: 0.8484 - val_root_mean_squared_error: 0.8454 - 71ms/epoch - 5ms/step
# Epoch 199/500
# 13/13 - 0s - loss: 1.0949 - root_mean_squared_error: 0.9808 - val_loss: 0.8293 - val_root_mean_squared_error: 0.8355 - 72ms/epoch - 6ms/step
# Epoch 200/500
# 13/13 - 0s - loss: 1.1133 - root_mean_squared_error: 0.9913 - val_loss: 0.8245 - val_root_mean_squared_error: 0.8332 - 72ms/epoch - 6ms/step
# Epoch 201/500
# 13/13 - 0s - loss: 1.1437 - root_mean_squared_error: 1.0068 - val_loss: 0.8085 - val_root_mean_squared_error: 0.8240 - 73ms/epoch - 6ms/step
# Epoch 202/500
# 13/13 - 0s - loss: 1.1117 - root_mean_squared_error: 0.9910 - val_loss: 0.8336 - val_root_mean_squared_error: 0.8384 - 72ms/epoch - 6ms/step
# Epoch 203/500
# 13/13 - 0s - loss: 1.1199 - root_mean_squared_error: 0.9951 - val_loss: 0.7977 - val_root_mean_squared_error: 0.8180 - 72ms/epoch - 6ms/step
# Epoch 204/500
# 13/13 - 0s - loss: 1.0924 - root_mean_squared_error: 0.9816 - val_loss: 0.9039 - val_root_mean_squared_error: 0.8808 - 71ms/epoch - 5ms/step
# Epoch 205/500
# 13/13 - 0s - loss: 1.0914 - root_mean_squared_error: 0.9818 - val_loss: 0.8332 - val_root_mean_squared_error: 0.8398 - 72ms/epoch - 6ms/step
# Epoch 206/500
# 13/13 - 0s - loss: 1.0796 - root_mean_squared_error: 0.9761 - val_loss: 0.8372 - val_root_mean_squared_error: 0.8434 - 75ms/epoch - 6ms/step
# Epoch 207/500
# 13/13 - 0s - loss: 1.1098 - root_mean_squared_error: 0.9921 - val_loss: 0.8760 - val_root_mean_squared_error: 0.8660 - 75ms/epoch - 6ms/step
# Epoch 208/500
# 13/13 - 0s - loss: 1.0980 - root_mean_squared_error: 0.9861 - val_loss: 0.8054 - val_root_mean_squared_error: 0.8250 - 76ms/epoch - 6ms/step
# Epoch 209/500
# 13/13 - 0s - loss: 1.0844 - root_mean_squared_error: 0.9795 - val_loss: 0.8672 - val_root_mean_squared_error: 0.8614 - 75ms/epoch - 6ms/step
# Epoch 210/500
# 13/13 - 0s - loss: 1.0797 - root_mean_squared_error: 0.9777 - val_loss: 0.8231 - val_root_mean_squared_error: 0.8364 - 76ms/epoch - 6ms/step
# Epoch 211/500
# 13/13 - 0s - loss: 1.0871 - root_mean_squared_error: 0.9819 - val_loss: 0.8793 - val_root_mean_squared_error: 0.8693 - 76ms/epoch - 6ms/step
# Epoch 212/500
# 13/13 - 0s - loss: 1.0864 - root_mean_squared_error: 0.9819 - val_loss: 0.8425 - val_root_mean_squared_error: 0.8496 - 75ms/epoch - 6ms/step
# Epoch 213/500
# 13/13 - 0s - loss: 1.0939 - root_mean_squared_error: 0.9862 - val_loss: 0.8220 - val_root_mean_squared_error: 0.8369 - 72ms/epoch - 6ms/step
# Epoch 214/500
# 13/13 - 0s - loss: 1.0839 - root_mean_squared_error: 0.9817 - val_loss: 0.8167 - val_root_mean_squared_error: 0.8346 - 73ms/epoch - 6ms/step
# Epoch 215/500
# 13/13 - 0s - loss: 1.0919 - root_mean_squared_error: 0.9861 - val_loss: 0.9297 - val_root_mean_squared_error: 0.8999 - 72ms/epoch - 6ms/step
# Epoch 216/500
# 13/13 - 0s - loss: 1.1226 - root_mean_squared_error: 1.0015 - val_loss: 0.8119 - val_root_mean_squared_error: 0.8322 - 72ms/epoch - 6ms/step
# Epoch 217/500
# 13/13 - 0s - loss: 1.0894 - root_mean_squared_error: 0.9849 - val_loss: 0.7968 - val_root_mean_squared_error: 0.8230 - 70ms/epoch - 5ms/step
# Epoch 218/500
# 13/13 - 0s - loss: 1.0788 - root_mean_squared_error: 0.9796 - val_loss: 0.7933 - val_root_mean_squared_error: 0.8212 - 72ms/epoch - 6ms/step
# Epoch 219/500
# 13/13 - 0s - loss: 1.1203 - root_mean_squared_error: 1.0009 - val_loss: 0.8268 - val_root_mean_squared_error: 0.8420 - 73ms/epoch - 6ms/step
# Epoch 220/500
# 13/13 - 0s - loss: 1.1023 - root_mean_squared_error: 0.9923 - val_loss: 0.8252 - val_root_mean_squared_error: 0.8410 - 75ms/epoch - 6ms/step
# Epoch 221/500
# 13/13 - 0s - loss: 1.1261 - root_mean_squared_error: 1.0041 - val_loss: 0.9740 - val_root_mean_squared_error: 0.9245 - 76ms/epoch - 6ms/step
# Epoch 222/500
# 13/13 - 0s - loss: 1.1056 - root_mean_squared_error: 0.9936 - val_loss: 0.9339 - val_root_mean_squared_error: 0.9035 - 76ms/epoch - 6ms/step
# Epoch 223/500
# 13/13 - 0s - loss: 1.0733 - root_mean_squared_error: 0.9776 - val_loss: 0.8646 - val_root_mean_squared_error: 0.8646 - 76ms/epoch - 6ms/step
# Epoch 224/500
# 13/13 - 0s - loss: 1.0842 - root_mean_squared_error: 0.9836 - val_loss: 0.8161 - val_root_mean_squared_error: 0.8361 - 76ms/epoch - 6ms/step
# Epoch 225/500
# 13/13 - 0s - loss: 1.0517 - root_mean_squared_error: 0.9670 - val_loss: 0.7847 - val_root_mean_squared_error: 0.8178 - 77ms/epoch - 6ms/step
# Epoch 226/500
# 13/13 - 0s - loss: 1.1047 - root_mean_squared_error: 0.9947 - val_loss: 0.9727 - val_root_mean_squared_error: 0.9253 - 77ms/epoch - 6ms/step
# Epoch 227/500
# 13/13 - 0s - loss: 1.1528 - root_mean_squared_error: 1.0186 - val_loss: 0.8895 - val_root_mean_squared_error: 0.8795 - 75ms/epoch - 6ms/step
# Epoch 228/500
# 13/13 - 0s - loss: 1.0927 - root_mean_squared_error: 0.9887 - val_loss: 0.8122 - val_root_mean_squared_error: 0.8348 - 71ms/epoch - 5ms/step
# Epoch 229/500
# 13/13 - 0s - loss: 1.1235 - root_mean_squared_error: 1.0041 - val_loss: 0.8355 - val_root_mean_squared_error: 0.8493 - 72ms/epoch - 6ms/step
# Epoch 230/500
# 13/13 - 0s - loss: 1.1121 - root_mean_squared_error: 0.9986 - val_loss: 0.8947 - val_root_mean_squared_error: 0.8832 - 71ms/epoch - 5ms/step
# Epoch 231/500
# 13/13 - 0s - loss: 1.0813 - root_mean_squared_error: 0.9830 - val_loss: 0.8867 - val_root_mean_squared_error: 0.8787 - 71ms/epoch - 5ms/step
# Epoch 232/500
# 13/13 - 0s - loss: 1.0852 - root_mean_squared_error: 0.9852 - val_loss: 0.7874 - val_root_mean_squared_error: 0.8208 - 72ms/epoch - 6ms/step
# Epoch 233/500
# 13/13 - 0s - loss: 1.0792 - root_mean_squared_error: 0.9827 - val_loss: 0.8302 - val_root_mean_squared_error: 0.8468 - 74ms/epoch - 6ms/step
# Epoch 234/500
# 13/13 - 0s - loss: 1.0561 - root_mean_squared_error: 0.9711 - val_loss: 0.8034 - val_root_mean_squared_error: 0.8309 - 73ms/epoch - 6ms/step
# Epoch 235/500
# 13/13 - 0s - loss: 1.0558 - root_mean_squared_error: 0.9713 - val_loss: 0.8277 - val_root_mean_squared_error: 0.8460 - 75ms/epoch - 6ms/step
# Epoch 236/500
# 13/13 - 0s - loss: 1.0842 - root_mean_squared_error: 0.9864 - val_loss: 0.8206 - val_root_mean_squared_error: 0.8426 - 76ms/epoch - 6ms/step
# Epoch 237/500
# 13/13 - 0s - loss: 1.0788 - root_mean_squared_error: 0.9839 - val_loss: 0.8501 - val_root_mean_squared_error: 0.8602 - 75ms/epoch - 6ms/step
# Epoch 238/500
# 13/13 - 0s - loss: 1.1220 - root_mean_squared_error: 1.0057 - val_loss: 0.8850 - val_root_mean_squared_error: 0.8796 - 77ms/epoch - 6ms/step
# Epoch 239/500
# 13/13 - 0s - loss: 1.0922 - root_mean_squared_error: 0.9906 - val_loss: 0.7915 - val_root_mean_squared_error: 0.8255 - 73ms/epoch - 6ms/step
# Epoch 240/500
# 13/13 - 0s - loss: 1.0525 - root_mean_squared_error: 0.9706 - val_loss: 0.9428 - val_root_mean_squared_error: 0.9125 - 74ms/epoch - 6ms/step
# Epoch 241/500
# 13/13 - 0s - loss: 1.0870 - root_mean_squared_error: 0.9886 - val_loss: 0.8151 - val_root_mean_squared_error: 0.8400 - 75ms/epoch - 6ms/step
# Epoch 242/500
# 13/13 - 0s - loss: 1.0851 - root_mean_squared_error: 0.9876 - val_loss: 0.9349 - val_root_mean_squared_error: 0.9085 - 75ms/epoch - 6ms/step
# Epoch 243/500
# 13/13 - 0s - loss: 1.0785 - root_mean_squared_error: 0.9846 - val_loss: 0.8403 - val_root_mean_squared_error: 0.8557 - 76ms/epoch - 6ms/step
# Epoch 244/500
# 13/13 - 0s - loss: 1.0654 - root_mean_squared_error: 0.9780 - val_loss: 0.8510 - val_root_mean_squared_error: 0.8615 - 76ms/epoch - 6ms/step
# Epoch 245/500
# 13/13 - 0s - loss: 1.0479 - root_mean_squared_error: 0.9696 - val_loss: 0.8153 - val_root_mean_squared_error: 0.8411 - 72ms/epoch - 6ms/step
# Epoch 246/500
# 13/13 - 0s - loss: 1.0742 - root_mean_squared_error: 0.9832 - val_loss: 0.8158 - val_root_mean_squared_error: 0.8417 - 72ms/epoch - 6ms/step
# Epoch 247/500
# 13/13 - 0s - loss: 1.0557 - root_mean_squared_error: 0.9739 - val_loss: 0.8055 - val_root_mean_squared_error: 0.8357 - 72ms/epoch - 6ms/step
# Epoch 248/500
# 13/13 - 0s - loss: 1.0928 - root_mean_squared_error: 0.9931 - val_loss: 0.8652 - val_root_mean_squared_error: 0.8712 - 73ms/epoch - 6ms/step
# Epoch 249/500
# 13/13 - 0s - loss: 1.1002 - root_mean_squared_error: 0.9968 - val_loss: 0.8028 - val_root_mean_squared_error: 0.8344 - 71ms/epoch - 5ms/step
# Epoch 250/500
# 13/13 - 0s - loss: 1.0595 - root_mean_squared_error: 0.9762 - val_loss: 0.7767 - val_root_mean_squared_error: 0.8188 - 74ms/epoch - 6ms/step
# Epoch 251/500
# 13/13 - 0s - loss: 1.0447 - root_mean_squared_error: 0.9690 - val_loss: 0.8038 - val_root_mean_squared_error: 0.8355 - 72ms/epoch - 6ms/step
# Epoch 252/500
# 13/13 - 0s - loss: 1.1433 - root_mean_squared_error: 1.0190 - val_loss: 0.8388 - val_root_mean_squared_error: 0.8565 - 73ms/epoch - 6ms/step
# Epoch 253/500
# 13/13 - 0s - loss: 1.0911 - root_mean_squared_error: 0.9928 - val_loss: 0.9074 - val_root_mean_squared_error: 0.8949 - 72ms/epoch - 6ms/step
# Epoch 254/500
# 13/13 - 0s - loss: 1.0689 - root_mean_squared_error: 0.9817 - val_loss: 0.7963 - val_root_mean_squared_error: 0.8314 - 75ms/epoch - 6ms/step
# Epoch 255/500
# 13/13 - 0s - loss: 1.0822 - root_mean_squared_error: 0.9885 - val_loss: 0.8238 - val_root_mean_squared_error: 0.8476 - 77ms/epoch - 6ms/step
# Epoch 256/500
# 13/13 - 0s - loss: 1.0661 - root_mean_squared_error: 0.9802 - val_loss: 0.8039 - val_root_mean_squared_error: 0.8355 - 76ms/epoch - 6ms/step
# Epoch 257/500
# 13/13 - 0s - loss: 1.0642 - root_mean_squared_error: 0.9792 - val_loss: 0.7914 - val_root_mean_squared_error: 0.8279 - 76ms/epoch - 6ms/step
# Epoch 258/500
# 13/13 - 0s - loss: 1.1099 - root_mean_squared_error: 1.0023 - val_loss: 0.8255 - val_root_mean_squared_error: 0.8481 - 76ms/epoch - 6ms/step
# Epoch 259/500
# 13/13 - 0s - loss: 1.0800 - root_mean_squared_error: 0.9872 - val_loss: 0.7942 - val_root_mean_squared_error: 0.8307 - 76ms/epoch - 6ms/step
# Epoch 260/500
# 13/13 - 0s - loss: 1.0635 - root_mean_squared_error: 0.9794 - val_loss: 0.8315 - val_root_mean_squared_error: 0.8527 - 76ms/epoch - 6ms/step
# Epoch 261/500
# 13/13 - 0s - loss: 1.0651 - root_mean_squared_error: 0.9804 - val_loss: 0.9542 - val_root_mean_squared_error: 0.9220 - 75ms/epoch - 6ms/step
# Epoch 262/500
# 13/13 - 0s - loss: 1.0817 - root_mean_squared_error: 0.9891 - val_loss: 0.8138 - val_root_mean_squared_error: 0.8437 - 73ms/epoch - 6ms/step
# Epoch 263/500
# 13/13 - 0s - loss: 1.1261 - root_mean_squared_error: 1.0115 - val_loss: 0.9197 - val_root_mean_squared_error: 0.9031 - 73ms/epoch - 6ms/step
# Epoch 264/500
# 13/13 - 0s - loss: 1.0513 - root_mean_squared_error: 0.9739 - val_loss: 0.7997 - val_root_mean_squared_error: 0.8350 - 72ms/epoch - 6ms/step
# Epoch 265/500
# 13/13 - 0s - loss: 1.0655 - root_mean_squared_error: 0.9810 - val_loss: 0.9716 - val_root_mean_squared_error: 0.9314 - 71ms/epoch - 5ms/step
# Epoch 266/500
# 13/13 - 0s - loss: 1.0442 - root_mean_squared_error: 0.9702 - val_loss: 0.8584 - val_root_mean_squared_error: 0.8693 - 73ms/epoch - 6ms/step
# Epoch 267/500
# 13/13 - 0s - loss: 1.0464 - root_mean_squared_error: 0.9716 - val_loss: 0.8009 - val_root_mean_squared_error: 0.8355 - 74ms/epoch - 6ms/step
# Epoch 268/500
# 13/13 - 0s - loss: 1.0765 - root_mean_squared_error: 0.9872 - val_loss: 0.8010 - val_root_mean_squared_error: 0.8371 - 72ms/epoch - 6ms/step
# Epoch 269/500
# 13/13 - 0s - loss: 1.0765 - root_mean_squared_error: 0.9876 - val_loss: 0.8922 - val_root_mean_squared_error: 0.8892 - 74ms/epoch - 6ms/step
# Epoch 270/500
# 13/13 - 0s - loss: 1.0566 - root_mean_squared_error: 0.9778 - val_loss: 0.8619 - val_root_mean_squared_error: 0.8728 - 74ms/epoch - 6ms/step
# Epoch 271/500
# 13/13 - 0s - loss: 1.0874 - root_mean_squared_error: 0.9931 - val_loss: 0.8067 - val_root_mean_squared_error: 0.8401 - 75ms/epoch - 6ms/step
# Epoch 272/500
# 13/13 - 0s - loss: 1.0526 - root_mean_squared_error: 0.9755 - val_loss: 0.8433 - val_root_mean_squared_error: 0.8620 - 76ms/epoch - 6ms/step
# Epoch 273/500
# 13/13 - 0s - loss: 1.0477 - root_mean_squared_error: 0.9733 - val_loss: 0.8088 - val_root_mean_squared_error: 0.8415 - 78ms/epoch - 6ms/step
# Epoch 274/500
# 13/13 - 0s - loss: 1.0521 - root_mean_squared_error: 0.9757 - val_loss: 0.7885 - val_root_mean_squared_error: 0.8304 - 77ms/epoch - 6ms/step
# Epoch 275/500
# 13/13 - 0s - loss: 1.0516 - root_mean_squared_error: 0.9759 - val_loss: 0.9283 - val_root_mean_squared_error: 0.9105 - 77ms/epoch - 6ms/step
# Epoch 276/500
# 13/13 - 0s - loss: 1.0853 - root_mean_squared_error: 0.9932 - val_loss: 0.8067 - val_root_mean_squared_error: 0.8421 - 77ms/epoch - 6ms/step
# Epoch 277/500
# 13/13 - 0s - loss: 1.0918 - root_mean_squared_error: 0.9966 - val_loss: 1.1302 - val_root_mean_squared_error: 1.0156 - 76ms/epoch - 6ms/step
# Epoch 278/500
# 13/13 - 0s - loss: 1.0987 - root_mean_squared_error: 0.9999 - val_loss: 0.8436 - val_root_mean_squared_error: 0.8632 - 76ms/epoch - 6ms/step
# Epoch 279/500
# 13/13 - 0s - loss: 1.0494 - root_mean_squared_error: 0.9749 - val_loss: 0.8680 - val_root_mean_squared_error: 0.8769 - 74ms/epoch - 6ms/step
# Epoch 280/500
# 13/13 - 0s - loss: 1.0603 - root_mean_squared_error: 0.9807 - val_loss: 0.8410 - val_root_mean_squared_error: 0.8612 - 71ms/epoch - 5ms/step
# Epoch 281/500
# 13/13 - 0s - loss: 1.0720 - root_mean_squared_error: 0.9865 - val_loss: 0.8004 - val_root_mean_squared_error: 0.8376 - 72ms/epoch - 6ms/step
# Epoch 282/500
# ...
# Epoch 398/500
# 13/13 - 0s - loss: 1.0172 - root_mean_squared_error: 0.9669 - val_loss: 0.8037 - val_root_mean_squared_error: 0.8491 - 71ms/epoch - 5ms/step
# Epoch 399/500
# 13/13 - 0s - loss: 0.9892 - root_mean_squared_error: 0.9525 - val_loss: 0.8321 - val_root_mean_squared_error: 0.8661 - 72ms/epoch - 6ms/step
# Epoch 400/500
# 13/13 - 0s - loss: 0.9989 - root_mean_squared_error: 0.9578 - val_loss: 0.7644 - val_root_mean_squared_error: 0.8264 - 72ms/epoch - 6ms/step
# Epoch 401/500
# 13/13 - 0s - loss: 1.0000 - root_mean_squared_error: 0.9585 - val_loss: 0.7973 - val_root_mean_squared_error: 0.8463 - 73ms/epoch - 6ms/step
# Epoch 402/500
# 13/13 - 0s - loss: 1.0231 - root_mean_squared_error: 0.9705 - val_loss: 0.7853 - val_root_mean_squared_error: 0.8395 - 72ms/epoch - 6ms/step
# Epoch 403/500
# 13/13 - 0s - loss: 1.0035 - root_mean_squared_error: 0.9606 - val_loss: 0.9083 - val_root_mean_squared_error: 0.9104 - 77ms/epoch - 6ms/step
# Epoch 404/500
# 13/13 - 0s - loss: 1.0453 - root_mean_squared_error: 0.9821 - val_loss: 0.9233 - val_root_mean_squared_error: 0.9169 - 76ms/epoch - 6ms/step
# Epoch 405/500
# 13/13 - 0s - loss: 1.0362 - root_mean_squared_error: 0.9770 - val_loss: 0.7766 - val_root_mean_squared_error: 0.8342 - 75ms/epoch - 6ms/step
# Epoch 406/500
# 13/13 - 0s - loss: 1.0147 - root_mean_squared_error: 0.9662 - val_loss: 0.9775 - val_root_mean_squared_error: 0.9474 - 72ms/epoch - 6ms/step
# Epoch 407/500
# 13/13 - 0s - loss: 0.9978 - root_mean_squared_error: 0.9577 - val_loss: 0.7811 - val_root_mean_squared_error: 0.8370 - 72ms/epoch - 6ms/step
# Epoch 408/500
# 13/13 - 0s - loss: 0.9817 - root_mean_squared_error: 0.9492 - val_loss: 0.8528 - val_root_mean_squared_error: 0.8787 - 71ms/epoch - 5ms/step
# Epoch 409/500
# 13/13 - 0s - loss: 0.9896 - root_mean_squared_error: 0.9536 - val_loss: 0.8783 - val_root_mean_squared_error: 0.8939 - 72ms/epoch - 6ms/step
# Epoch 410/500
# 13/13 - 0s - loss: 1.0143 - root_mean_squared_error: 0.9666 - val_loss: 0.9169 - val_root_mean_squared_error: 0.9147 - 73ms/epoch - 6ms/step
# Epoch 411/500
# 13/13 - 0s - loss: 1.0029 - root_mean_squared_error: 0.9606 - val_loss: 0.8442 - val_root_mean_squared_error: 0.8745 - 72ms/epoch - 6ms/step
# Epoch 412/500
# 13/13 - 0s - loss: 1.0069 - root_mean_squared_error: 0.9629 - val_loss: 0.8728 - val_root_mean_squared_error: 0.8904 - 74ms/epoch - 6ms/step
# Epoch 413/500
# 13/13 - 0s - loss: 1.0579 - root_mean_squared_error: 0.9889 - val_loss: 0.8526 - val_root_mean_squared_error: 0.8793 - 76ms/epoch - 6ms/step
# Epoch 414/500
# 13/13 - 0s - loss: 1.0330 - root_mean_squared_error: 0.9760 - val_loss: 0.8404 - val_root_mean_squared_error: 0.8722 - 76ms/epoch - 6ms/step
# Epoch 415/500
# 13/13 - 0s - loss: 1.0146 - root_mean_squared_error: 0.9668 - val_loss: 0.8598 - val_root_mean_squared_error: 0.8832 - 72ms/epoch - 6ms/step
# Epoch 416/500
# 13/13 - 0s - loss: 1.0017 - root_mean_squared_error: 0.9597 - val_loss: 0.9097 - val_root_mean_squared_error: 0.9107 - 72ms/epoch - 6ms/step
# Epoch 417/500
# 13/13 - 0s - loss: 1.0259 - root_mean_squared_error: 0.9724 - val_loss: 0.9317 - val_root_mean_squared_error: 0.9222 - 72ms/epoch - 6ms/step
# Epoch 418/500
# 13/13 - 0s - loss: 1.0435 - root_mean_squared_error: 0.9814 - val_loss: 0.7897 - val_root_mean_squared_error: 0.8424 - 72ms/epoch - 6ms/step
# Epoch 419/500
# 13/13 - 0s - loss: 0.9942 - root_mean_squared_error: 0.9557 - val_loss: 0.8131 - val_root_mean_squared_error: 0.8556 - 74ms/epoch - 6ms/step
# Epoch 420/500
# 13/13 - 0s - loss: 0.9889 - root_mean_squared_error: 0.9531 - val_loss: 0.8599 - val_root_mean_squared_error: 0.8825 - 77ms/epoch - 6ms/step
# Epoch 421/500
# 13/13 - 0s - loss: 1.0099 - root_mean_squared_error: 0.9640 - val_loss: 0.8403 - val_root_mean_squared_error: 0.8716 - 77ms/epoch - 6ms/step
# Epoch 422/500
# 13/13 - 0s - loss: 0.9709 - root_mean_squared_error: 0.9437 - val_loss: 0.9500 - val_root_mean_squared_error: 0.9330 - 72ms/epoch - 6ms/step
# Epoch 423/500
# 13/13 - 0s - loss: 1.0070 - root_mean_squared_error: 0.9629 - val_loss: 0.8747 - val_root_mean_squared_error: 0.8919 - 73ms/epoch - 6ms/step
# Epoch 424/500
# 13/13 - 0s - loss: 0.9894 - root_mean_squared_error: 0.9538 - val_loss: 0.8229 - val_root_mean_squared_error: 0.8626 - 72ms/epoch - 6ms/step
# Epoch 425/500
# 13/13 - 0s - loss: 1.0159 - root_mean_squared_error: 0.9677 - val_loss: 0.8042 - val_root_mean_squared_error: 0.8506 - 76ms/epoch - 6ms/step
# Epoch 426/500
# 13/13 - 0s - loss: 0.9869 - root_mean_squared_error: 0.9524 - val_loss: 0.8748 - val_root_mean_squared_error: 0.8919 - 77ms/epoch - 6ms/step
# Epoch 427/500
# 13/13 - 0s - loss: 1.0194 - root_mean_squared_error: 0.9695 - val_loss: 0.9252 - val_root_mean_squared_error: 0.9195 - 73ms/epoch - 6ms/step
# Epoch 428/500
# 13/13 - 0s - loss: 0.9860 - root_mean_squared_error: 0.9522 - val_loss: 0.9147 - val_root_mean_squared_error: 0.9137 - 71ms/epoch - 5ms/step
# Epoch 429/500
# 13/13 - 0s - loss: 0.9839 - root_mean_squared_error: 0.9512 - val_loss: 0.8174 - val_root_mean_squared_error: 0.8597 - 72ms/epoch - 6ms/step
# Epoch 430/500
# 13/13 - 0s - loss: 0.9860 - root_mean_squared_error: 0.9523 - val_loss: 0.8925 - val_root_mean_squared_error: 0.9012 - 77ms/epoch - 6ms/step
# Epoch 431/500
# 13/13 - 0s - loss: 1.0001 - root_mean_squared_error: 0.9598 - val_loss: 0.7881 - val_root_mean_squared_error: 0.8423 - 76ms/epoch - 6ms/step
# Epoch 432/500
# 13/13 - 0s - loss: 0.9750 - root_mean_squared_error: 0.9467 - val_loss: 0.8705 - val_root_mean_squared_error: 0.8897 - 73ms/epoch - 6ms/step
# Epoch 433/500
# 13/13 - 0s - loss: 0.9812 - root_mean_squared_error: 0.9501 - val_loss: 0.9121 - val_root_mean_squared_error: 0.9132 - 73ms/epoch - 6ms/step
# Epoch 434/500
# 13/13 - 0s - loss: 0.9778 - root_mean_squared_error: 0.9482 - val_loss: 0.8360 - val_root_mean_squared_error: 0.8703 - 73ms/epoch - 6ms/step
# Epoch 435/500
# 13/13 - 0s - loss: 0.9849 - root_mean_squared_error: 0.9520 - val_loss: 0.7853 - val_root_mean_squared_error: 0.8404 - 78ms/epoch - 6ms/step
# Epoch 436/500
# 13/13 - 0s - loss: 0.9821 - root_mean_squared_error: 0.9503 - val_loss: 0.8888 - val_root_mean_squared_error: 0.9003 - 77ms/epoch - 6ms/step
# Epoch 437/500
# 13/13 - 0s - loss: 0.9945 - root_mean_squared_error: 0.9571 - val_loss: 0.8045 - val_root_mean_squared_error: 0.8521 - 73ms/epoch - 6ms/step
# Epoch 438/500
# 13/13 - 0s - loss: 0.9929 - root_mean_squared_error: 0.9561 - val_loss: 0.8255 - val_root_mean_squared_error: 0.8650 - 73ms/epoch - 6ms/step
# Epoch 439/500
# 13/13 - 0s - loss: 0.9881 - root_mean_squared_error: 0.9540 - val_loss: 0.9786 - val_root_mean_squared_error: 0.9488 - 75ms/epoch - 6ms/step
# Epoch 440/500
# 13/13 - 0s - loss: 0.9819 - root_mean_squared_error: 0.9508 - val_loss: 0.8935 - val_root_mean_squared_error: 0.9030 - 75ms/epoch - 6ms/step
# Epoch 441/500
# 13/13 - 0s - loss: 0.9786 - root_mean_squared_error: 0.9491 - val_loss: 0.8723 - val_root_mean_squared_error: 0.8915 - 73ms/epoch - 6ms/step
# Epoch 442/500
# 13/13 - 0s - loss: 0.9595 - root_mean_squared_error: 0.9391 - val_loss: 0.8655 - val_root_mean_squared_error: 0.8879 - 77ms/epoch - 6ms/step
# Epoch 443/500
# 13/13 - 0s - loss: 0.9677 - root_mean_squared_error: 0.9435 - val_loss: 0.8599 - val_root_mean_squared_error: 0.8846 - 79ms/epoch - 6ms/step
# Epoch 444/500
# 13/13 - 0s - loss: 0.9704 - root_mean_squared_error: 0.9449 - val_loss: 0.8741 - val_root_mean_squared_error: 0.8923 - 78ms/epoch - 6ms/step
# Epoch 445/500
# 13/13 - 0s - loss: 0.9778 - root_mean_squared_error: 0.9489 - val_loss: 0.9987 - val_root_mean_squared_error: 0.9601 - 75ms/epoch - 6ms/step
# Epoch 446/500
# 13/13 - 0s - loss: 0.9789 - root_mean_squared_error: 0.9494 - val_loss: 0.7988 - val_root_mean_squared_error: 0.8493 - 73ms/epoch - 6ms/step
# Epoch 447/500
# 13/13 - 0s - loss: 0.9679 - root_mean_squared_error: 0.9435 - val_loss: 0.7923 - val_root_mean_squared_error: 0.8457 - 73ms/epoch - 6ms/step
# Epoch 448/500
# 13/13 - 0s - loss: 0.9776 - root_mean_squared_error: 0.9491 - val_loss: 0.8549 - val_root_mean_squared_error: 0.8814 - 73ms/epoch - 6ms/step
# Epoch 449/500
# 13/13 - 0s - loss: 0.9622 - root_mean_squared_error: 0.9408 - val_loss: 0.8327 - val_root_mean_squared_error: 0.8701 - 73ms/epoch - 6ms/step
# Epoch 450/500
# 13/13 - 0s - loss: 0.9705 - root_mean_squared_error: 0.9454 - val_loss: 0.8227 - val_root_mean_squared_error: 0.8632 - 72ms/epoch - 6ms/step
# Epoch 451/500
# 13/13 - 0s - loss: 0.9644 - root_mean_squared_error: 0.9420 - val_loss: 0.7954 - val_root_mean_squared_error: 0.8481 - 76ms/epoch - 6ms/step
# Epoch 452/500
# 13/13 - 0s - loss: 0.9746 - root_mean_squared_error: 0.9476 - val_loss: 0.8056 - val_root_mean_squared_error: 0.8539 - 76ms/epoch - 6ms/step
# Epoch 453/500
# 13/13 - 0s - loss: 0.9670 - root_mean_squared_error: 0.9436 - val_loss: 0.9398 - val_root_mean_squared_error: 0.9287 - 76ms/epoch - 6ms/step
# Epoch 454/500
# 13/13 - 0s - loss: 0.9996 - root_mean_squared_error: 0.9607 - val_loss: 0.8583 - val_root_mean_squared_error: 0.8837 - 73ms/epoch - 6ms/step
# Epoch 455/500
# 13/13 - 0s - loss: 1.0161 - root_mean_squared_error: 0.9691 - val_loss: 0.8562 - val_root_mean_squared_error: 0.8830 - 74ms/epoch - 6ms/step
# Epoch 456/500
# 13/13 - 0s - loss: 1.0048 - root_mean_squared_error: 0.9634 - val_loss: 0.8250 - val_root_mean_squared_error: 0.8653 - 73ms/epoch - 6ms/step
# Epoch 457/500
# 13/13 - 0s - loss: 1.0162 - root_mean_squared_error: 0.9695 - val_loss: 0.9106 - val_root_mean_squared_error: 0.9126 - 73ms/epoch - 6ms/step
# Epoch 458/500
# 13/13 - 0s - loss: 0.9570 - root_mean_squared_error: 0.9380 - val_loss: 0.8250 - val_root_mean_squared_error: 0.8647 - 72ms/epoch - 6ms/step
# Epoch 459/500
# 13/13 - 0s - loss: 0.9796 - root_mean_squared_error: 0.9502 - val_loss: 0.9194 - val_root_mean_squared_error: 0.9176 - 73ms/epoch - 6ms/step
# Epoch 460/500
# 13/13 - 0s - loss: 0.9793 - root_mean_squared_error: 0.9499 - val_loss: 0.7905 - val_root_mean_squared_error: 0.8451 - 77ms/epoch - 6ms/step
# Epoch 461/500
# 13/13 - 0s - loss: 0.9651 - root_mean_squared_error: 0.9422 - val_loss: 0.8147 - val_root_mean_squared_error: 0.8586 - 78ms/epoch - 6ms/step
# Epoch 462/500
# 13/13 - 0s - loss: 0.9562 - root_mean_squared_error: 0.9376 - val_loss: 0.8050 - val_root_mean_squared_error: 0.8532 - 77ms/epoch - 6ms/step
# Epoch 463/500
# 13/13 - 0s - loss: 0.9756 - root_mean_squared_error: 0.9479 - val_loss: 0.8170 - val_root_mean_squared_error: 0.8604 - 78ms/epoch - 6ms/step
# Epoch 464/500
# 13/13 - 0s - loss: 0.9484 - root_mean_squared_error: 0.9337 - val_loss: 0.9697 - val_root_mean_squared_error: 0.9449 - 78ms/epoch - 6ms/step
# Epoch 465/500
# 13/13 - 0s - loss: 1.0003 - root_mean_squared_error: 0.9612 - val_loss: 0.8248 - val_root_mean_squared_error: 0.8658 - 77ms/epoch - 6ms/step
# Epoch 466/500
# 13/13 - 0s - loss: 1.0183 - root_mean_squared_error: 0.9705 - val_loss: 0.7903 - val_root_mean_squared_error: 0.8444 - 77ms/epoch - 6ms/step
# Epoch 467/500
# 13/13 - 0s - loss: 0.9899 - root_mean_squared_error: 0.9554 - val_loss: 0.8672 - val_root_mean_squared_error: 0.8885 - 77ms/epoch - 6ms/step
# Epoch 468/500
# 13/13 - 0s - loss: 0.9665 - root_mean_squared_error: 0.9430 - val_loss: 0.7913 - val_root_mean_squared_error: 0.8453 - 77ms/epoch - 6ms/step
# Epoch 469/500
# 13/13 - 0s - loss: 0.9696 - root_mean_squared_error: 0.9447 - val_loss: 0.7904 - val_root_mean_squared_error: 0.8446 - 78ms/epoch - 6ms/step
# Epoch 470/500
# 13/13 - 0s - loss: 0.9665 - root_mean_squared_error: 0.9432 - val_loss: 0.8539 - val_root_mean_squared_error: 0.8818 - 77ms/epoch - 6ms/step
# Epoch 471/500
# 13/13 - 0s - loss: 0.9788 - root_mean_squared_error: 0.9500 - val_loss: 0.8517 - val_root_mean_squared_error: 0.8807 - 77ms/epoch - 6ms/step
# Epoch 472/500
# 13/13 - 0s - loss: 0.9670 - root_mean_squared_error: 0.9435 - val_loss: 0.8563 - val_root_mean_squared_error: 0.8827 - 77ms/epoch - 6ms/step
# Epoch 473/500
# 13/13 - 0s - loss: 0.9414 - root_mean_squared_error: 0.9301 - val_loss: 0.8029 - val_root_mean_squared_error: 0.8521 - 79ms/epoch - 6ms/step
# Epoch 474/500
# 13/13 - 0s - loss: 0.9558 - root_mean_squared_error: 0.9378 - val_loss: 0.8325 - val_root_mean_squared_error: 0.8701 - 76ms/epoch - 6ms/step
# Epoch 475/500
# 13/13 - 0s - loss: 0.9360 - root_mean_squared_error: 0.9272 - val_loss: 0.9272 - val_root_mean_squared_error: 0.9226 - 73ms/epoch - 6ms/step
# Epoch 476/500
# 13/13 - 0s - loss: 0.9943 - root_mean_squared_error: 0.9580 - val_loss: 0.7966 - val_root_mean_squared_error: 0.8491 - 72ms/epoch - 6ms/step
# Epoch 477/500
# 13/13 - 0s - loss: 0.9899 - root_mean_squared_error: 0.9556 - val_loss: 0.8079 - val_root_mean_squared_error: 0.8549 - 72ms/epoch - 6ms/step
# Epoch 478/500
# 13/13 - 0s - loss: 0.9318 - root_mean_squared_error: 0.9250 - val_loss: 0.8179 - val_root_mean_squared_error: 0.8613 - 72ms/epoch - 6ms/step
# Epoch 479/500
# 13/13 - 0s - loss: 0.9363 - root_mean_squared_error: 0.9276 - val_loss: 0.8075 - val_root_mean_squared_error: 0.8549 - 72ms/epoch - 6ms/step
# Epoch 480/500
# 13/13 - 0s - loss: 0.9546 - root_mean_squared_error: 0.9372 - val_loss: 0.8451 - val_root_mean_squared_error: 0.8770 - 73ms/epoch - 6ms/step
# Epoch 481/500
# 13/13 - 0s - loss: 0.9800 - root_mean_squared_error: 0.9507 - val_loss: 0.8025 - val_root_mean_squared_error: 0.8526 - 72ms/epoch - 6ms/step
# Epoch 482/500
# 13/13 - 0s - loss: 0.9800 - root_mean_squared_error: 0.9509 - val_loss: 0.8312 - val_root_mean_squared_error: 0.8695 - 72ms/epoch - 6ms/step
# Epoch 483/500
# 13/13 - 0s - loss: 0.9948 - root_mean_squared_error: 0.9587 - val_loss: 1.1074 - val_root_mean_squared_error: 1.0157 - 73ms/epoch - 6ms/step
# Epoch 484/500
# 13/13 - 0s - loss: 0.9651 - root_mean_squared_error: 0.9427 - val_loss: 0.8004 - val_root_mean_squared_error: 0.8509 - 73ms/epoch - 6ms/step
# Epoch 485/500
# 13/13 - 0s - loss: 0.9566 - root_mean_squared_error: 0.9383 - val_loss: 0.9094 - val_root_mean_squared_error: 0.9118 - 72ms/epoch - 6ms/step
# Epoch 486/500
# 13/13 - 0s - loss: 0.9653 - root_mean_squared_error: 0.9426 - val_loss: 0.7584 - val_root_mean_squared_error: 0.8262 - 71ms/epoch - 5ms/step
# Epoch 487/500
# 13/13 - 0s - loss: 0.9347 - root_mean_squared_error: 0.9266 - val_loss: 0.8126 - val_root_mean_squared_error: 0.8582 - 72ms/epoch - 6ms/step
# Epoch 488/500
# 13/13 - 0s - loss: 0.9448 - root_mean_squared_error: 0.9320 - val_loss: 0.8267 - val_root_mean_squared_error: 0.8666 - 73ms/epoch - 6ms/step
# Epoch 489/500
# 13/13 - 0s - loss: 0.9429 - root_mean_squared_error: 0.9314 - val_loss: 0.9534 - val_root_mean_squared_error: 0.9368 - 72ms/epoch - 6ms/step
# Epoch 490/500
# 13/13 - 0s - loss: 0.9951 - root_mean_squared_error: 0.9589 - val_loss: 0.8857 - val_root_mean_squared_error: 0.8998 - 72ms/epoch - 6ms/step
# Epoch 491/500
# 13/13 - 0s - loss: 0.9897 - root_mean_squared_error: 0.9562 - val_loss: 0.7987 - val_root_mean_squared_error: 0.8500 - 73ms/epoch - 6ms/step
# Epoch 492/500
# 13/13 - 0s - loss: 0.9504 - root_mean_squared_error: 0.9352 - val_loss: 0.8069 - val_root_mean_squared_error: 0.8552 - 73ms/epoch - 6ms/step
# Epoch 493/500
# 13/13 - 0s - loss: 0.9851 - root_mean_squared_error: 0.9535 - val_loss: 0.7896 - val_root_mean_squared_error: 0.8450 - 72ms/epoch - 6ms/step
# Epoch 494/500
# 13/13 - 0s - loss: 0.9678 - root_mean_squared_error: 0.9446 - val_loss: 0.8044 - val_root_mean_squared_error: 0.8532 - 73ms/epoch - 6ms/step
# Epoch 495/500
# 13/13 - 0s - loss: 0.9642 - root_mean_squared_error: 0.9423 - val_loss: 0.8583 - val_root_mean_squared_error: 0.8850 - 71ms/epoch - 5ms/step
# Epoch 496/500
# 13/13 - 0s - loss: 0.9681 - root_mean_squared_error: 0.9446 - val_loss: 0.8096 - val_root_mean_squared_error: 0.8560 - 71ms/epoch - 5ms/step
# Epoch 497/500
# 13/13 - 0s - loss: 0.9661 - root_mean_squared_error: 0.9433 - val_loss: 0.8210 - val_root_mean_squared_error: 0.8631 - 72ms/epoch - 6ms/step
# Epoch 498/500
# 13/13 - 0s - loss: 0.9429 - root_mean_squared_error: 0.9310 - val_loss: 0.8419 - val_root_mean_squared_error: 0.8751 - 72ms/epoch - 6ms/step
# Epoch 499/500
# 13/13 - 0s - loss: 0.9662 - root_mean_squared_error: 0.9435 - val_loss: 0.8266 - val_root_mean_squared_error: 0.8657 - 72ms/epoch - 6ms/step
# Epoch 500/500
# 13/13 - 0s - loss: 0.9408 - root_mean_squared_error: 0.9294 - val_loss: 0.8444 - val_root_mean_squared_error: 0.8764 - 73ms/epoch - 6ms/step

# %%
hist_df = pd.DataFrame(history.history)
hist_df.head()
# Out:
#         loss  root_mean_squared_error   val_loss  val_root_mean_squared_error
# 0  78.313629                 8.750354  30.464722                     5.358066
# 1  19.524923                 4.216512  15.682824                     3.734988
# 2  13.680722                 3.458240   9.106820                     2.720280
# 3   9.245243                 2.747510   6.317746                     2.152631
# 4   7.068060                 2.322468   5.441248                     1.944122

# %%
hist_df = hist_df.rename({'root_mean_squared_error': 'rmse', 
                          'val_root_mean_squared_error': 'val_rmse'}, 
                         axis = 1)
hist_df.head()
# Out:
#         loss      rmse   val_loss  val_rmse
# 0  78.313629  8.750354  30.464722  5.358066
# 1  19.524923  4.216512  15.682824  3.734988
# 2  13.680722  3.458240   9.106820  2.720280
# 3   9.245243  2.747510   6.317746  2.152631
# 4   7.068060  2.322468   5.441248  1.944122

# %%
plot_tf_hist(hist_df)

# %%
# make predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
y_pred = np.append(y_train_pred, y_test_pred)
# Out:
# 101/101 [==============================] - 0s 977us/step
# 2023-06-08 09:57:33.519664: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-08 09:57:33.520428: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-08 09:57:33.521137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 0s 1ms/step

# %%
res_df = y_df.copy()

res_df['pred'] = y_pred
#res_df['datetime'] = res_df['datetime'].dt.date
res_df.head()
# Out:
#                      datetime      temp      pred
# 24  2006-01-01 23:00:00+00:00  5.422222  4.908542
# 48  2006-01-02 23:00:00+00:00  1.694444  1.667748
# 72  2006-01-03 23:00:00+00:00  2.200000  1.870432
# 96  2006-01-04 23:00:00+00:00  1.666667  1.879627
# 120 2006-01-05 23:00:00+00:00  1.805556  2.464051

# %%
fig, ax = plt.subplots(figsize = (15,6))

res_df.plot(x='datetime', y=['temp','pred'], ax = ax);

ax.vlines(y_df.iloc[X_train.shape[0]]['datetime'], 
          y_df['temp'].min(), 
          y_df['temp'].max(), color = 'k', 
          linewidth=3.0, zorder=10, alpha =0.8)

ax.grid()
