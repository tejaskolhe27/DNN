# %% [markdown]
# # LECTURE 12
#
# ## RNN

# %%
###-----------------
### Import Libraries
###-----------------;

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from collections.abc import Callable
from typing import Literal

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler


import warnings as w
w.filterwarnings('ignore')
# %matplotlib inline
# Out:
# 2023-12-01 10:36:20.647514: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-01 10:36:20.697435: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 10:36:20.697465: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 10:36:20.698505: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 10:36:20.706190: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-01 10:36:21.719319: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
###----------------
### Some parameters
###----------------

inpDir = '../input'
outDir = '../output'

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 200 # number of epochs
ALPHA = 0.01 # learning rate
NUM_SAMPLES = 1280 # How many samples we want to generate
NOISE = 0.2 # Noise to be introduced in the data
TEST_SIZE = 0.2
BATCH_SIZE = 32
TRAIN_SIZE = 14496

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

CMAP = 'coolwarm' # plt.cm.Spectral

plt.rcParams.update(params)

# %% [markdown]
# ## Helper Functions

# %%
###-----------------------------------
### Function to plot Decision boundary
###-----------------------------------

def fn_plot_decision_boundary(pred_func: Callable[[], np.float64], X_tr: np.ndarray, y_tr: np.ndarray, X_ts :  np.ndarray, y_ts:  np.ndarray,):
    '''
        Attrib:
           pred_func : function based on predict method of the classifier
           X_tr : train feature matrix
           y_tr : train labels
           X_ts : test feature matrix
           y_ts : test labels
       Return:
           None
    '''

    # Set min and max values and give it some padding
    xMin, xMax = X_tr[:, 0].min() - .05, X_tr[:, 0].max() + .05
    yMin, yMax = X_tr[:, 1].min() - .05, X_tr[:, 1].max() + .05

    # grid size for mesh grid
    h = 0.01

    # Generate a grid of points with distance 'h' between them
    xx, yy = np.meshgrid(np.arange(xMin, xMax, h), np.arange(yMin, yMax, h))

    # Predict the function value for the whole grid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])

    # Make its shape same as that of xx
    Z = Z.reshape(xx.shape)

    fig = plt.figure()
    ax = fig.add_axes(111)

    # Now we have Z value corresponding to each of the combination of xx and yy
    # Plot the contour and training examples
    ax.contourf(xx, yy, Z, cmap=CMAP) #, alpha = 0.8

    # Plotting scatter for train data
    ax.scatter(X_tr[:, 0], X_tr[:, 1],
               c=np.argmax(y_tr, axis = 1), # y_tr has two columns
               s=30, edgecolor='k', cmap=plt.cm.coolwarm)


    # Plotting scatter for test data
    ax.scatter(X_ts[:, 0], X_ts[:, 1],
               c=np.argmax(y_ts, axis = 1), # y_tr has two columns ,
                                  s=150, marker = '*',edgecolor='k', cmap=plt.cm.inferno )

# %% [markdown]
# ## Generate Data Set

# %%
data_df=pd.read_csv('weatherHistory.csv')

# %%
data_df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# 1             9.355556                  7.227778      0.86            14.2646
# 2             9.377778                  9.377778      0.89             3.9284
# 3             8.288889                  5.944444      0.83            14.1036
# 4             8.755556                  6.977778      0.83            11.0446
# ...                ...                       ...       ...                ...
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                       251.0          15.8263         0.0
# 1                       259.0          15.8263         0.0
# 2                       204.0          14.9569         0.0
# 3                       269.0          15.8263         0.0
# 4                       259.0          15.8263         0.0
# ...                       ...              ...         ...
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 0                   1015.13       Partly cloudy throughout the day.
# 1                   1015.63       Partly cloudy throughout the day.
# 2                   1015.94       Partly cloudy throughout the day.
# 3                   1016.41       Partly cloudy throughout the day.
# 4                   1016.51       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
data_df['Time'] = pd.to_datetime(data_df['Formatted Date'],utc=True)

# %%
data_df.drop('Formatted Date',axis=1,inplace=True)

# %%
data_df.head()
# Out:
#          Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0  Partly Cloudy        rain         9.472222                  7.388889
# 1  Partly Cloudy        rain         9.355556                  7.227778
# 2  Mostly Cloudy        rain         9.377778                  9.377778
# 3  Partly Cloudy        rain         8.288889                  5.944444
# 4  Mostly Cloudy        rain         8.755556                  6.977778
#
#    Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# 0      0.89            14.1197                   251.0          15.8263
# 1      0.86            14.2646                   259.0          15.8263
# 2      0.89             3.9284                   204.0          14.9569
# 3      0.83            14.1036                   269.0          15.8263
# 4      0.83            11.0446                   259.0          15.8263
#
#    Loud Cover  Pressure (millibars)                      Daily Summary  \
# 0         0.0               1015.13  Partly cloudy throughout the day.
# 1         0.0               1015.63  Partly cloudy throughout the day.
# 2         0.0               1015.94  Partly cloudy throughout the day.
# 3         0.0               1016.41  Partly cloudy throughout the day.
# 4         0.0               1016.51  Partly cloudy throughout the day.
#
#                        Time
# 0 2006-03-31 22:00:00+00:00
# 1 2006-03-31 23:00:00+00:00
# 2 2006-04-01 00:00:00+00:00
# 3 2006-04-01 01:00:00+00:00
# 4 2006-04-01 02:00:00+00:00

# %%
data_df['Time'].plot();

# %%
temp_df = data_df[['Time','Temperature (C)']]
temp_df = temp_df.sort_values('Time',axis=0,ascending=True)
temp_df = temp_df.reset_index(drop=True)
temp_df.head()
# Out:
#                        Time  Temperature (C)
# 0 2005-12-31 23:00:00+00:00         0.577778
# 1 2006-01-01 00:00:00+00:00         1.161111
# 2 2006-01-01 01:00:00+00:00         1.666667
# 3 2006-01-01 02:00:00+00:00         1.711111
# 4 2006-01-01 03:00:00+00:00         1.183333

# %%
temp_df['Temperature (C)'].plot();

# %%
temp_df = temp_df.rename({'Temperature (C)': 'temp'}, axis=1)
temp_df.head()
# Out:
#                        Time      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
temp_df.reset_index(drop=True, inplace = True)
temp_df.head()
# Out:
#                        Time      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
temp_df.shape
# Out:
# (96453, 2)

# %% [markdown]
# ### Prepare Model:

# %%
# h_units=100

# input_shape=(1,10000)

# model = tf.keras.Sequential()

# model.add(tf.keras.layers.SimpleRNN(units=h_units,
#                                    input_shape=input_shape,
#                                    activation='tanh'))

# model.add(tf.keras.layers.Dense(units=1,
#                                activation='linear'))

# %%
# model.summary()

# %%
# wax = model.get_weights()[0].shape
# waa = model.get_weights()[1].shape
# baa = model.get_weights()[2].shape
# way = model.get_weights()[3].shape
# bay = model.get_weights()[4].shape

# print ('Shape of Matrix:')
# print ('Wax = ', wax,'; Waa = ', waa, '; baa = ', baa,'; Way = ', way,'; bay = ', bay)

# %%
time_step = 24

# %%
y_idx = np.arange(time_step, temp_df.shape[0], time_step)
y_df = temp_df.iloc[y_idx]
y_df.head()
# Out:
#                          Time      temp
# 24  2006-01-01 23:00:00+00:00  5.422222
# 48  2006-01-02 23:00:00+00:00  1.694444
# 72  2006-01-03 23:00:00+00:00  2.200000
# 96  2006-01-04 23:00:00+00:00  1.666667
# 120 2006-01-05 23:00:00+00:00  1.805556

# %%
y_idx
# Out:
# array([   24,    48,    72, ..., 96384, 96408, 96432])

# %%
y_df.shape, len(y_df)*time_step
# Out:
# ((4018, 2), 96432)

# %%
X_df = temp_df.iloc[range(len(y_df) * time_step)]

# %%
X_df['temp'].values.shape,y_df.shape
# Out:
# ((96432,), (4018, 2))

# %%
X = np.reshape(X_df['temp'].values, (y_df.shape[0], time_step))
X.shape
# Out:
# (4018, 24)

# %%
X = X[:, :23]
X.shape
# Out:
# (4018, 23)

# %%
#3D Array
X = np.reshape(X, (X.shape[0], X.shape[1], 1))
X.shape
# Out:
# (4018, 23, 1)

# %%
split = int(y_df.shape[0] * (1-TEST_SIZE))
X_train = X[:split]
X_test = X[split:]
y_train = y_df['temp'].values[:split]
y_test = y_df['temp'].values[split:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3214, 23, 1), (804, 23, 1), (3214,), (804,))

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y_df['temp'],
                                             random_state=RANDOM_STATE,
                                            shuffle=True)

xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((3013, 23, 1), (1005, 23, 1), (3013,), (1005,))

# %%
h_units = 64
input_shape=(23, 1 ) # we are using one feature only.

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.SimpleRNN(units = h_units, 
                                    input_shape = input_shape, 
                                    activation = 'tanh'))

model.add(tf.keras.layers.Dense(1, activation = 'linear'))

model.compile(loss='mean_squared_error', optimizer='adam', 
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 4289 (16.75 KB)
# Trainable params: 4289 (16.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(xtrain, ytrain,
                    epochs=EPOCHS, 
                    validation_data=(xtest, ytest),
                    batch_size= BATCH_SIZE, 
                    verbose=1)
# Out:
# Epoch 1/200
# 95/95 [==============================] - 3s 16ms/step - loss: 62.1619 - root_mean_squared_error: 7.8843 - val_loss: 22.6625 - val_root_mean_squared_error: 4.7605
# Epoch 2/200
# 95/95 [==============================] - 1s 12ms/step - loss: 14.3406 - root_mean_squared_error: 3.7869 - val_loss: 10.1598 - val_root_mean_squared_error: 3.1874
# Epoch 3/200
# 95/95 [==============================] - 1s 12ms/step - loss: 6.7927 - root_mean_squared_error: 2.6063 - val_loss: 5.5221 - val_root_mean_squared_error: 2.3499
# Epoch 4/200
# 95/95 [==============================] - 1s 12ms/step - loss: 3.8817 - root_mean_squared_error: 1.9702 - val_loss: 3.5036 - val_root_mean_squared_error: 1.8718
# Epoch 5/200
# 95/95 [==============================] - 1s 12ms/step - loss: 2.5991 - root_mean_squared_error: 1.6122 - val_loss: 2.5898 - val_root_mean_squared_error: 1.6093
# Epoch 6/200
# 95/95 [==============================] - 1s 12ms/step - loss: 2.0019 - root_mean_squared_error: 1.4149 - val_loss: 2.0558 - val_root_mean_squared_error: 1.4338
# Epoch 7/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.6411 - root_mean_squared_error: 1.2811 - val_loss: 1.7444 - val_root_mean_squared_error: 1.3207
# Epoch 8/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.4301 - root_mean_squared_error: 1.1959 - val_loss: 1.6012 - val_root_mean_squared_error: 1.2654
# Epoch 9/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.3345 - root_mean_squared_error: 1.1552 - val_loss: 1.4214 - val_root_mean_squared_error: 1.1922
# Epoch 10/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.2179 - root_mean_squared_error: 1.1036 - val_loss: 1.3446 - val_root_mean_squared_error: 1.1596
# Epoch 11/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.1935 - root_mean_squared_error: 1.0925 - val_loss: 1.3420 - val_root_mean_squared_error: 1.1585
# Epoch 12/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.1471 - root_mean_squared_error: 1.0710 - val_loss: 1.1949 - val_root_mean_squared_error: 1.0931
# Epoch 13/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0731 - root_mean_squared_error: 1.0359 - val_loss: 1.1810 - val_root_mean_squared_error: 1.0867
# Epoch 14/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0473 - root_mean_squared_error: 1.0234 - val_loss: 1.1160 - val_root_mean_squared_error: 1.0564
# Epoch 15/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0238 - root_mean_squared_error: 1.0118 - val_loss: 1.1305 - val_root_mean_squared_error: 1.0633
# Epoch 16/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0152 - root_mean_squared_error: 1.0076 - val_loss: 1.1776 - val_root_mean_squared_error: 1.0852
# Epoch 17/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0132 - root_mean_squared_error: 1.0066 - val_loss: 1.0616 - val_root_mean_squared_error: 1.0303
# Epoch 18/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9941 - root_mean_squared_error: 0.9970 - val_loss: 1.3522 - val_root_mean_squared_error: 1.1629
# Epoch 19/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0491 - root_mean_squared_error: 1.0243 - val_loss: 1.0724 - val_root_mean_squared_error: 1.0356
# Epoch 20/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0172 - root_mean_squared_error: 1.0086 - val_loss: 1.0473 - val_root_mean_squared_error: 1.0234
# Epoch 21/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0135 - root_mean_squared_error: 1.0067 - val_loss: 1.0829 - val_root_mean_squared_error: 1.0406
# Epoch 22/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.1557 - root_mean_squared_error: 1.0751 - val_loss: 2.1082 - val_root_mean_squared_error: 1.4520
# Epoch 23/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.2826 - root_mean_squared_error: 1.1325 - val_loss: 1.2423 - val_root_mean_squared_error: 1.1146
# Epoch 24/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0904 - root_mean_squared_error: 1.0442 - val_loss: 1.1637 - val_root_mean_squared_error: 1.0787
# Epoch 25/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0387 - root_mean_squared_error: 1.0191 - val_loss: 1.0528 - val_root_mean_squared_error: 1.0261
# Epoch 26/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9897 - root_mean_squared_error: 0.9948 - val_loss: 1.0505 - val_root_mean_squared_error: 1.0249
# Epoch 27/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9823 - root_mean_squared_error: 0.9911 - val_loss: 1.0406 - val_root_mean_squared_error: 1.0201
# Epoch 28/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0428 - root_mean_squared_error: 1.0212 - val_loss: 1.0717 - val_root_mean_squared_error: 1.0353
# Epoch 29/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0011 - root_mean_squared_error: 1.0006 - val_loss: 1.0243 - val_root_mean_squared_error: 1.0121
# Epoch 30/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9877 - root_mean_squared_error: 0.9938 - val_loss: 0.9955 - val_root_mean_squared_error: 0.9977
# Epoch 31/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9525 - root_mean_squared_error: 0.9759 - val_loss: 0.9766 - val_root_mean_squared_error: 0.9882
# Epoch 32/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9535 - root_mean_squared_error: 0.9765 - val_loss: 1.0011 - val_root_mean_squared_error: 1.0006
# Epoch 33/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9571 - root_mean_squared_error: 0.9783 - val_loss: 1.0565 - val_root_mean_squared_error: 1.0279
# Epoch 34/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9424 - root_mean_squared_error: 0.9708 - val_loss: 0.9823 - val_root_mean_squared_error: 0.9911
# Epoch 35/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9309 - root_mean_squared_error: 0.9648 - val_loss: 1.0127 - val_root_mean_squared_error: 1.0063
# Epoch 36/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9261 - root_mean_squared_error: 0.9623 - val_loss: 0.9718 - val_root_mean_squared_error: 0.9858
# Epoch 37/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9340 - root_mean_squared_error: 0.9664 - val_loss: 0.9913 - val_root_mean_squared_error: 0.9956
# Epoch 38/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9701 - root_mean_squared_error: 0.9849 - val_loss: 0.9798 - val_root_mean_squared_error: 0.9899
# Epoch 39/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9342 - root_mean_squared_error: 0.9665 - val_loss: 0.9922 - val_root_mean_squared_error: 0.9961
# Epoch 40/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9441 - root_mean_squared_error: 0.9717 - val_loss: 0.9709 - val_root_mean_squared_error: 0.9853
# Epoch 41/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9373 - root_mean_squared_error: 0.9681 - val_loss: 0.9579 - val_root_mean_squared_error: 0.9787
# Epoch 42/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9285 - root_mean_squared_error: 0.9636 - val_loss: 0.9570 - val_root_mean_squared_error: 0.9783
# Epoch 43/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9291 - root_mean_squared_error: 0.9639 - val_loss: 1.0290 - val_root_mean_squared_error: 1.0144
# Epoch 44/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9427 - root_mean_squared_error: 0.9709 - val_loss: 0.9984 - val_root_mean_squared_error: 0.9992
# Epoch 45/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9262 - root_mean_squared_error: 0.9624 - val_loss: 1.0025 - val_root_mean_squared_error: 1.0012
# Epoch 46/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9279 - root_mean_squared_error: 0.9633 - val_loss: 0.9696 - val_root_mean_squared_error: 0.9847
# Epoch 47/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9272 - root_mean_squared_error: 0.9629 - val_loss: 0.9775 - val_root_mean_squared_error: 0.9887
# Epoch 48/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9185 - root_mean_squared_error: 0.9584 - val_loss: 0.9719 - val_root_mean_squared_error: 0.9858
# Epoch 49/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9132 - root_mean_squared_error: 0.9556 - val_loss: 1.0016 - val_root_mean_squared_error: 1.0008
# Epoch 50/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9056 - root_mean_squared_error: 0.9516 - val_loss: 0.9786 - val_root_mean_squared_error: 0.9892
# Epoch 51/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9158 - root_mean_squared_error: 0.9570 - val_loss: 0.9452 - val_root_mean_squared_error: 0.9722
# Epoch 52/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9098 - root_mean_squared_error: 0.9538 - val_loss: 0.9603 - val_root_mean_squared_error: 0.9799
# Epoch 53/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9111 - root_mean_squared_error: 0.9545 - val_loss: 0.9652 - val_root_mean_squared_error: 0.9825
# Epoch 54/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9066 - root_mean_squared_error: 0.9522 - val_loss: 0.9533 - val_root_mean_squared_error: 0.9764
# Epoch 55/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9106 - root_mean_squared_error: 0.9542 - val_loss: 0.9719 - val_root_mean_squared_error: 0.9859
# Epoch 56/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9204 - root_mean_squared_error: 0.9594 - val_loss: 0.9426 - val_root_mean_squared_error: 0.9709
# Epoch 57/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9104 - root_mean_squared_error: 0.9542 - val_loss: 0.9618 - val_root_mean_squared_error: 0.9807
# Epoch 58/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9685 - root_mean_squared_error: 0.9841 - val_loss: 0.9803 - val_root_mean_squared_error: 0.9901
# Epoch 59/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9106 - root_mean_squared_error: 0.9543 - val_loss: 1.0121 - val_root_mean_squared_error: 1.0060
# Epoch 60/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9083 - root_mean_squared_error: 0.9531 - val_loss: 0.9648 - val_root_mean_squared_error: 0.9822
# Epoch 61/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9041 - root_mean_squared_error: 0.9509 - val_loss: 0.9432 - val_root_mean_squared_error: 0.9712
# Epoch 62/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9085 - root_mean_squared_error: 0.9532 - val_loss: 0.9562 - val_root_mean_squared_error: 0.9778
# Epoch 63/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9039 - root_mean_squared_error: 0.9507 - val_loss: 0.9804 - val_root_mean_squared_error: 0.9901
# Epoch 64/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9050 - root_mean_squared_error: 0.9513 - val_loss: 0.9447 - val_root_mean_squared_error: 0.9720
# Epoch 65/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9040 - root_mean_squared_error: 0.9508 - val_loss: 0.9714 - val_root_mean_squared_error: 0.9856
# Epoch 66/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9065 - root_mean_squared_error: 0.9521 - val_loss: 0.9817 - val_root_mean_squared_error: 0.9908
# Epoch 67/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9171 - root_mean_squared_error: 0.9576 - val_loss: 0.9659 - val_root_mean_squared_error: 0.9828
# Epoch 68/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9129 - root_mean_squared_error: 0.9555 - val_loss: 1.0137 - val_root_mean_squared_error: 1.0068
# Epoch 69/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9123 - root_mean_squared_error: 0.9552 - val_loss: 1.0067 - val_root_mean_squared_error: 1.0033
# Epoch 70/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9055 - root_mean_squared_error: 0.9516 - val_loss: 0.9992 - val_root_mean_squared_error: 0.9996
# Epoch 71/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8939 - root_mean_squared_error: 0.9455 - val_loss: 0.9838 - val_root_mean_squared_error: 0.9919
# Epoch 72/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9705 - root_mean_squared_error: 0.9851 - val_loss: 0.9687 - val_root_mean_squared_error: 0.9842
# Epoch 73/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9351 - root_mean_squared_error: 0.9670 - val_loss: 0.9614 - val_root_mean_squared_error: 0.9805
# Epoch 74/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9004 - root_mean_squared_error: 0.9489 - val_loss: 1.0267 - val_root_mean_squared_error: 1.0133
# Epoch 75/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9309 - root_mean_squared_error: 0.9648 - val_loss: 0.9751 - val_root_mean_squared_error: 0.9875
# Epoch 76/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9076 - root_mean_squared_error: 0.9527 - val_loss: 0.9748 - val_root_mean_squared_error: 0.9873
# Epoch 77/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9042 - root_mean_squared_error: 0.9509 - val_loss: 0.9698 - val_root_mean_squared_error: 0.9848
# Epoch 78/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8975 - root_mean_squared_error: 0.9473 - val_loss: 0.9567 - val_root_mean_squared_error: 0.9781
# Epoch 79/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9860 - root_mean_squared_error: 0.9930 - val_loss: 0.9739 - val_root_mean_squared_error: 0.9869
# Epoch 80/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9255 - root_mean_squared_error: 0.9620 - val_loss: 1.0227 - val_root_mean_squared_error: 1.0113
# Epoch 81/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9213 - root_mean_squared_error: 0.9598 - val_loss: 1.0212 - val_root_mean_squared_error: 1.0106
# Epoch 82/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9396 - root_mean_squared_error: 0.9694 - val_loss: 0.9633 - val_root_mean_squared_error: 0.9815
# Epoch 83/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9061 - root_mean_squared_error: 0.9519 - val_loss: 0.9603 - val_root_mean_squared_error: 0.9800
# Epoch 84/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9194 - root_mean_squared_error: 0.9588 - val_loss: 0.9699 - val_root_mean_squared_error: 0.9848
# Epoch 85/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9161 - root_mean_squared_error: 0.9571 - val_loss: 0.9300 - val_root_mean_squared_error: 0.9644
# Epoch 86/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8959 - root_mean_squared_error: 0.9465 - val_loss: 0.9554 - val_root_mean_squared_error: 0.9775
# Epoch 87/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9040 - root_mean_squared_error: 0.9508 - val_loss: 0.9885 - val_root_mean_squared_error: 0.9942
# Epoch 88/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9031 - root_mean_squared_error: 0.9503 - val_loss: 0.9544 - val_root_mean_squared_error: 0.9769
# Epoch 89/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9118 - root_mean_squared_error: 0.9549 - val_loss: 0.9553 - val_root_mean_squared_error: 0.9774
# Epoch 90/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8993 - root_mean_squared_error: 0.9483 - val_loss: 0.9325 - val_root_mean_squared_error: 0.9657
# Epoch 91/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8916 - root_mean_squared_error: 0.9443 - val_loss: 1.0750 - val_root_mean_squared_error: 1.0368
# Epoch 92/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9131 - root_mean_squared_error: 0.9556 - val_loss: 0.9428 - val_root_mean_squared_error: 0.9710
# Epoch 93/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8870 - root_mean_squared_error: 0.9418 - val_loss: 0.9618 - val_root_mean_squared_error: 0.9807
# Epoch 94/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8935 - root_mean_squared_error: 0.9452 - val_loss: 0.9435 - val_root_mean_squared_error: 0.9713
# Epoch 95/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8866 - root_mean_squared_error: 0.9416 - val_loss: 0.9311 - val_root_mean_squared_error: 0.9649
# Epoch 96/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8947 - root_mean_squared_error: 0.9459 - val_loss: 0.9352 - val_root_mean_squared_error: 0.9671
# Epoch 97/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8894 - root_mean_squared_error: 0.9431 - val_loss: 0.9428 - val_root_mean_squared_error: 0.9710
# Epoch 98/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8857 - root_mean_squared_error: 0.9411 - val_loss: 0.9512 - val_root_mean_squared_error: 0.9753
# Epoch 99/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8917 - root_mean_squared_error: 0.9443 - val_loss: 0.9471 - val_root_mean_squared_error: 0.9732
# Epoch 100/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8830 - root_mean_squared_error: 0.9397 - val_loss: 0.9913 - val_root_mean_squared_error: 0.9956
# Epoch 101/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9038 - root_mean_squared_error: 0.9507 - val_loss: 0.9354 - val_root_mean_squared_error: 0.9672
# Epoch 102/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8960 - root_mean_squared_error: 0.9466 - val_loss: 0.9595 - val_root_mean_squared_error: 0.9795
# Epoch 103/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8951 - root_mean_squared_error: 0.9461 - val_loss: 0.9516 - val_root_mean_squared_error: 0.9755
# Epoch 104/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9139 - root_mean_squared_error: 0.9560 - val_loss: 0.9765 - val_root_mean_squared_error: 0.9882
# Epoch 105/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8788 - root_mean_squared_error: 0.9374 - val_loss: 0.9503 - val_root_mean_squared_error: 0.9748
# Epoch 106/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8845 - root_mean_squared_error: 0.9405 - val_loss: 0.9722 - val_root_mean_squared_error: 0.9860
# Epoch 107/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9033 - root_mean_squared_error: 0.9504 - val_loss: 1.0323 - val_root_mean_squared_error: 1.0160
# Epoch 108/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8829 - root_mean_squared_error: 0.9396 - val_loss: 0.9621 - val_root_mean_squared_error: 0.9809
# Epoch 109/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8731 - root_mean_squared_error: 0.9344 - val_loss: 0.9761 - val_root_mean_squared_error: 0.9880
# Epoch 110/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8923 - root_mean_squared_error: 0.9446 - val_loss: 0.9728 - val_root_mean_squared_error: 0.9863
# Epoch 111/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8874 - root_mean_squared_error: 0.9420 - val_loss: 0.9580 - val_root_mean_squared_error: 0.9788
# Epoch 112/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8759 - root_mean_squared_error: 0.9359 - val_loss: 0.9547 - val_root_mean_squared_error: 0.9771
# Epoch 113/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8861 - root_mean_squared_error: 0.9413 - val_loss: 1.0021 - val_root_mean_squared_error: 1.0010
# Epoch 114/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8862 - root_mean_squared_error: 0.9414 - val_loss: 0.9393 - val_root_mean_squared_error: 0.9692
# Epoch 115/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9318 - root_mean_squared_error: 0.9653 - val_loss: 1.0632 - val_root_mean_squared_error: 1.0311
# Epoch 116/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.5320 - root_mean_squared_error: 1.2378 - val_loss: 4.3083 - val_root_mean_squared_error: 2.0756
# Epoch 117/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.5195 - root_mean_squared_error: 1.2327 - val_loss: 1.2175 - val_root_mean_squared_error: 1.1034
# Epoch 118/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0819 - root_mean_squared_error: 1.0401 - val_loss: 1.0931 - val_root_mean_squared_error: 1.0455
# Epoch 119/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0180 - root_mean_squared_error: 1.0089 - val_loss: 1.0333 - val_root_mean_squared_error: 1.0165
# Epoch 120/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9778 - root_mean_squared_error: 0.9889 - val_loss: 1.0188 - val_root_mean_squared_error: 1.0093
# Epoch 121/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0016 - root_mean_squared_error: 1.0008 - val_loss: 1.0112 - val_root_mean_squared_error: 1.0056
# Epoch 122/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9600 - root_mean_squared_error: 0.9798 - val_loss: 0.9622 - val_root_mean_squared_error: 0.9809
# Epoch 123/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9578 - root_mean_squared_error: 0.9787 - val_loss: 0.9910 - val_root_mean_squared_error: 0.9955
# Epoch 124/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9366 - root_mean_squared_error: 0.9678 - val_loss: 0.9643 - val_root_mean_squared_error: 0.9820
# Epoch 125/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9341 - root_mean_squared_error: 0.9665 - val_loss: 0.9803 - val_root_mean_squared_error: 0.9901
# Epoch 126/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9346 - root_mean_squared_error: 0.9667 - val_loss: 0.9572 - val_root_mean_squared_error: 0.9784
# Epoch 127/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9238 - root_mean_squared_error: 0.9611 - val_loss: 0.9995 - val_root_mean_squared_error: 0.9998
# Epoch 128/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9334 - root_mean_squared_error: 0.9661 - val_loss: 0.9419 - val_root_mean_squared_error: 0.9705
# Epoch 129/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9259 - root_mean_squared_error: 0.9622 - val_loss: 0.9546 - val_root_mean_squared_error: 0.9770
# Epoch 130/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9244 - root_mean_squared_error: 0.9615 - val_loss: 0.9337 - val_root_mean_squared_error: 0.9663
# Epoch 131/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9352 - root_mean_squared_error: 0.9670 - val_loss: 0.9708 - val_root_mean_squared_error: 0.9853
# Epoch 132/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9359 - root_mean_squared_error: 0.9674 - val_loss: 0.9464 - val_root_mean_squared_error: 0.9728
# Epoch 133/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9347 - root_mean_squared_error: 0.9668 - val_loss: 0.9399 - val_root_mean_squared_error: 0.9695
# Epoch 134/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9462 - root_mean_squared_error: 0.9727 - val_loss: 0.9327 - val_root_mean_squared_error: 0.9658
# Epoch 135/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9375 - root_mean_squared_error: 0.9682 - val_loss: 0.9545 - val_root_mean_squared_error: 0.9770
# Epoch 136/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9318 - root_mean_squared_error: 0.9653 - val_loss: 0.9573 - val_root_mean_squared_error: 0.9784
# Epoch 137/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9290 - root_mean_squared_error: 0.9639 - val_loss: 0.9420 - val_root_mean_squared_error: 0.9706
# Epoch 138/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9277 - root_mean_squared_error: 0.9631 - val_loss: 0.9674 - val_root_mean_squared_error: 0.9836
# Epoch 139/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9399 - root_mean_squared_error: 0.9695 - val_loss: 0.9992 - val_root_mean_squared_error: 0.9996
# Epoch 140/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9197 - root_mean_squared_error: 0.9590 - val_loss: 0.9289 - val_root_mean_squared_error: 0.9638
# Epoch 141/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9187 - root_mean_squared_error: 0.9585 - val_loss: 1.0299 - val_root_mean_squared_error: 1.0149
# Epoch 142/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9156 - root_mean_squared_error: 0.9569 - val_loss: 0.9521 - val_root_mean_squared_error: 0.9758
# Epoch 143/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9484 - root_mean_squared_error: 0.9739 - val_loss: 1.0412 - val_root_mean_squared_error: 1.0204
# Epoch 144/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9348 - root_mean_squared_error: 0.9668 - val_loss: 0.9311 - val_root_mean_squared_error: 0.9649
# Epoch 145/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9093 - root_mean_squared_error: 0.9536 - val_loss: 0.9581 - val_root_mean_squared_error: 0.9788
# Epoch 146/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9120 - root_mean_squared_error: 0.9550 - val_loss: 0.9469 - val_root_mean_squared_error: 0.9731
# Epoch 147/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9152 - root_mean_squared_error: 0.9567 - val_loss: 0.9460 - val_root_mean_squared_error: 0.9726
# Epoch 148/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9104 - root_mean_squared_error: 0.9542 - val_loss: 0.9315 - val_root_mean_squared_error: 0.9652
# Epoch 149/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9288 - root_mean_squared_error: 0.9638 - val_loss: 0.9412 - val_root_mean_squared_error: 0.9702
# Epoch 150/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9125 - root_mean_squared_error: 0.9553 - val_loss: 0.9818 - val_root_mean_squared_error: 0.9909
# Epoch 151/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9249 - root_mean_squared_error: 0.9617 - val_loss: 0.9729 - val_root_mean_squared_error: 0.9864
# Epoch 152/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9149 - root_mean_squared_error: 0.9565 - val_loss: 1.0093 - val_root_mean_squared_error: 1.0046
# Epoch 153/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9221 - root_mean_squared_error: 0.9602 - val_loss: 0.9585 - val_root_mean_squared_error: 0.9791
# Epoch 154/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9090 - root_mean_squared_error: 0.9534 - val_loss: 0.9747 - val_root_mean_squared_error: 0.9873
# Epoch 155/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9194 - root_mean_squared_error: 0.9588 - val_loss: 0.9670 - val_root_mean_squared_error: 0.9834
# Epoch 156/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9103 - root_mean_squared_error: 0.9541 - val_loss: 0.9518 - val_root_mean_squared_error: 0.9756
# Epoch 157/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9132 - root_mean_squared_error: 0.9556 - val_loss: 0.9448 - val_root_mean_squared_error: 0.9720
# Epoch 158/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9017 - root_mean_squared_error: 0.9496 - val_loss: 0.9586 - val_root_mean_squared_error: 0.9791
# Epoch 159/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9244 - root_mean_squared_error: 0.9615 - val_loss: 0.9726 - val_root_mean_squared_error: 0.9862
# Epoch 160/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9140 - root_mean_squared_error: 0.9560 - val_loss: 0.9522 - val_root_mean_squared_error: 0.9758
# Epoch 161/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9128 - root_mean_squared_error: 0.9554 - val_loss: 0.9446 - val_root_mean_squared_error: 0.9719
# Epoch 162/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9138 - root_mean_squared_error: 0.9559 - val_loss: 0.9326 - val_root_mean_squared_error: 0.9657
# Epoch 163/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9504 - root_mean_squared_error: 0.9749 - val_loss: 0.9323 - val_root_mean_squared_error: 0.9655
# Epoch 164/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9072 - root_mean_squared_error: 0.9525 - val_loss: 0.9332 - val_root_mean_squared_error: 0.9660
# Epoch 165/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0092 - root_mean_squared_error: 1.0046 - val_loss: 1.0230 - val_root_mean_squared_error: 1.0114
# Epoch 166/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9826 - root_mean_squared_error: 0.9913 - val_loss: 0.9970 - val_root_mean_squared_error: 0.9985
# Epoch 167/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9645 - root_mean_squared_error: 0.9821 - val_loss: 1.0103 - val_root_mean_squared_error: 1.0051
# Epoch 168/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9639 - root_mean_squared_error: 0.9818 - val_loss: 0.9959 - val_root_mean_squared_error: 0.9979
# Epoch 169/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9309 - root_mean_squared_error: 0.9648 - val_loss: 0.9737 - val_root_mean_squared_error: 0.9868
# Epoch 170/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9314 - root_mean_squared_error: 0.9651 - val_loss: 0.9746 - val_root_mean_squared_error: 0.9872
# Epoch 171/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9250 - root_mean_squared_error: 0.9618 - val_loss: 1.0024 - val_root_mean_squared_error: 1.0012
# Epoch 172/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9495 - root_mean_squared_error: 0.9744 - val_loss: 0.9559 - val_root_mean_squared_error: 0.9777
# Epoch 173/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9356 - root_mean_squared_error: 0.9673 - val_loss: 0.9729 - val_root_mean_squared_error: 0.9863
# Epoch 174/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9245 - root_mean_squared_error: 0.9615 - val_loss: 0.9636 - val_root_mean_squared_error: 0.9816
# Epoch 175/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.4196 - root_mean_squared_error: 1.1915 - val_loss: 1.3471 - val_root_mean_squared_error: 1.1607
# Epoch 176/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.1338 - root_mean_squared_error: 1.0648 - val_loss: 1.0554 - val_root_mean_squared_error: 1.0273
# Epoch 177/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0356 - root_mean_squared_error: 1.0176 - val_loss: 0.9839 - val_root_mean_squared_error: 0.9919
# Epoch 178/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0065 - root_mean_squared_error: 1.0033 - val_loss: 0.9842 - val_root_mean_squared_error: 0.9921
# Epoch 179/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0171 - root_mean_squared_error: 1.0085 - val_loss: 1.1276 - val_root_mean_squared_error: 1.0619
# Epoch 180/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0429 - root_mean_squared_error: 1.0212 - val_loss: 0.9810 - val_root_mean_squared_error: 0.9905
# Epoch 181/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9804 - root_mean_squared_error: 0.9901 - val_loss: 0.9711 - val_root_mean_squared_error: 0.9854
# Epoch 182/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9517 - root_mean_squared_error: 0.9755 - val_loss: 0.9521 - val_root_mean_squared_error: 0.9758
# Epoch 183/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9352 - root_mean_squared_error: 0.9671 - val_loss: 0.9560 - val_root_mean_squared_error: 0.9778
# Epoch 184/200
# 95/95 [==============================] - 1s 12ms/step - loss: 1.0018 - root_mean_squared_error: 1.0009 - val_loss: 0.9725 - val_root_mean_squared_error: 0.9862
# Epoch 185/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9689 - root_mean_squared_error: 0.9843 - val_loss: 1.0414 - val_root_mean_squared_error: 1.0205
# Epoch 186/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9591 - root_mean_squared_error: 0.9794 - val_loss: 0.9832 - val_root_mean_squared_error: 0.9916
# Epoch 187/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9422 - root_mean_squared_error: 0.9707 - val_loss: 1.0116 - val_root_mean_squared_error: 1.0058
# Epoch 188/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9346 - root_mean_squared_error: 0.9667 - val_loss: 0.9759 - val_root_mean_squared_error: 0.9879
# Epoch 189/200
# 95/95 [==============================] - 1s 13ms/step - loss: 0.9907 - root_mean_squared_error: 0.9953 - val_loss: 1.0105 - val_root_mean_squared_error: 1.0053
# Epoch 190/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9349 - root_mean_squared_error: 0.9669 - val_loss: 0.9826 - val_root_mean_squared_error: 0.9913
# Epoch 191/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9121 - root_mean_squared_error: 0.9551 - val_loss: 0.9573 - val_root_mean_squared_error: 0.9784
# Epoch 192/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9093 - root_mean_squared_error: 0.9536 - val_loss: 0.9819 - val_root_mean_squared_error: 0.9909
# Epoch 193/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9087 - root_mean_squared_error: 0.9533 - val_loss: 0.9506 - val_root_mean_squared_error: 0.9750
# Epoch 194/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.8966 - root_mean_squared_error: 0.9469 - val_loss: 0.9420 - val_root_mean_squared_error: 0.9705
# Epoch 195/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9002 - root_mean_squared_error: 0.9488 - val_loss: 0.9622 - val_root_mean_squared_error: 0.9809
# Epoch 196/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9070 - root_mean_squared_error: 0.9524 - val_loss: 0.9716 - val_root_mean_squared_error: 0.9857
# Epoch 197/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9175 - root_mean_squared_error: 0.9578 - val_loss: 0.9526 - val_root_mean_squared_error: 0.9760
# Epoch 198/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9200 - root_mean_squared_error: 0.9592 - val_loss: 0.9417 - val_root_mean_squared_error: 0.9704
# Epoch 199/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9205 - root_mean_squared_error: 0.9594 - val_loss: 0.9649 - val_root_mean_squared_error: 0.9823
# Epoch 200/200
# 95/95 [==============================] - 1s 12ms/step - loss: 0.9269 - root_mean_squared_error: 0.9628 - val_loss: 0.9429 - val_root_mean_squared_error: 0.9710

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_tf_hist(hist_df):
    '''
    Args:
      hist_df : pandas Dataframe with four columns
                For 'x' values, we will use index
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(y1.capitalize(),
                           hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "{}: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(y2.capitalize(),
                           hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
hist_df = pd.DataFrame(history.history)
hist_df = hist_df.rename({'root_mean_squared_error': 'rmse', 'val_root_mean_squared_error' : 'val_rmse'}, axis=1)


plot_tf_hist(hist_df)

# %%
# make predictions
y_train_pred = model.predict(xtrain)
y_test_pred = model.predict(xtest)
y_pred = np.append(y_train_pred, y_test_pred)
# Out:
# 95/95 [==============================] - 1s 5ms/step
# 32/32 [==============================] - 0s 5ms/step

# %%
res_df = y_df.copy()
res_df['pred'] = y_pred
res_df['Time'] = res_df['Time'].dt.date
res_df.head()
# Out:
#            Time      temp       pred
# 24   2006-01-01  5.422222   2.890596
# 48   2006-01-02  1.694444  11.529876
# 72   2006-01-03  2.200000   2.461681
# 96   2006-01-04  1.666667  16.083111
# 120  2006-01-05  1.805556   9.755459

# %%
res_df.tail()
# Out:
#              Time      temp       pred
# 96336  2016-12-27 -1.627778  -3.064978
# 96360  2016-12-28 -1.677778   2.595552
# 96384  2016-12-29 -1.727778  17.287830
# 96408  2016-12-30 -1.777778  10.106465
# 96432  2016-12-31 -1.822222  -8.297336

# %%
fig, ax = plt.subplots(figsize = (15,6))

res_df.plot(x='Time', y=['temp','pred'], ax = ax);

ax.vlines(res_df.iloc[X_train.shape[0]]['Time'], 
          res_df['temp'].min(), 
          res_df['temp'].max(), color = 'k', 
          linewidth=3.0, zorder=10, alpha =0.8)

ax.grid()
