# %%
import tensorflow as tf
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
# Out:
# 2023-11-29 09:53:35.397052: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 09:53:35.459377: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 09:53:35.459421: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 09:53:35.460865: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 09:53:35.470356: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 09:53:36.527155: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
#!pip3 install --upgrade tensorflow

# %%
df = pd.read_csv('../ionosphere.data',header=None)
df.head()
# Out:
#    0   1        2        3        4        5        6        7        8   \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#         9   ...       25       26       27       28       29       30  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#         31       32       33  34
# 0 -0.54487  0.18641 -0.45300   g
# 1 -0.06288 -0.13738 -0.02447   b
# 2 -0.24180  0.56045 -0.38238   g
# 3  1.00000 -0.32382  1.00000   b
# 4 -0.59573 -0.04608 -0.65697   g
#
# [5 rows x 35 columns]

# %%
#df.drop(columns=[0,1],inplace=True)

# %%
x = df.iloc[:,:-1]
x
# Out:
#      0   1        2        3        4        5        6        7        8   \
# 0     1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1     1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2     1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3     1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4     1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..   ..  ..      ...      ...      ...      ...      ...      ...      ...
# 346   1   0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347   1   0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348   1   0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349   1   0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350   1   0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
#           9   ...       24       25       26       27       28       29  \
# 0    0.03760  ...  0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090
# 1   -0.04549  ... -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593
# 2    0.01198  ...  0.57528 -0.40220  0.58984 -0.22145  0.43100 -0.17365
# 3    0.00000  ...  1.00000  0.90695  0.51613  1.00000  1.00000 -0.20099
# 4   -0.16399  ...  0.03286 -0.65158  0.13290 -0.53206  0.02431 -0.62197
# ..       ...  ...      ...      ...      ...      ...      ...      ...
# 346 -0.04622  ...  0.95378 -0.04202  0.83479  0.00123  1.00000  0.12815
# 347  0.01606  ...  0.94520  0.01361  0.93522  0.04925  0.93159  0.08168
# 348  0.02446  ...  0.93988  0.03193  0.92489  0.02542  0.92120  0.02242
# 349  0.00110  ...  0.91050 -0.02099  0.89147 -0.07760  0.82983 -0.17238
# 350 -0.09139  ...  0.86467 -0.15114  0.81147 -0.04822  0.78207 -0.00703
#
#           30       31       32       33
# 0    0.42267 -0.54487  0.18641 -0.45300
# 1   -0.16626 -0.06288 -0.13738 -0.02447
# 2    0.60436 -0.24180  0.56045 -0.38238
# 3    0.25682  1.00000 -0.32382  1.00000
# 4   -0.05707 -0.59573 -0.04608 -0.65697
# ..       ...      ...      ...      ...
# 346  0.86660 -0.10714  0.90546 -0.04307
# 347  0.94066 -0.00035  0.91483  0.04712
# 348  0.92459  0.00442  0.92697 -0.00577
# 349  0.96022 -0.03757  0.87403 -0.16243
# 350  0.75747 -0.06678  0.85764 -0.06151
#
# [351 rows x 34 columns]

# %%
y = df.iloc[:,-1]
y
# Out:
# 0      g
# 1      b
# 2      g
# 3      b
# 4      g
#       ..
# 346    g
# 347    g
# 348    g
# 349    g
# 350    g
# Name: 34, Length: 351, dtype: object

# %%
lbl = LabelEncoder()
std = StandardScaler()

# %%
x = std.fit_transform(x)
x
# Out:
# array([[ 0.34843328,  0.        ,  0.71237237, ..., -1.05505394,
#         -0.3122206 , -0.99959483],
#        [ 0.34843328,  0.        ,  0.72164805, ..., -0.11521328,
#         -0.93260505, -0.08328554],
#        [ 0.34843328,  0.        ,  0.72164805, ..., -0.46409249,
#          0.40444328, -0.84859079],
#        ...,
#        [ 0.34843328,  0.        ,  0.61502805, ...,  0.01601615,
#          1.10669878, -0.04330004],
#        [ 0.34843328,  0.        ,  0.53267371, ..., -0.06586087,
#          1.00526528, -0.37828012],
#        [ 0.34843328,  0.        ,  0.41400137, ..., -0.12281796,
#          0.9738619 , -0.16248675]])

# %%
y = pd.get_dummies(y).to_numpy()
#y = lbl.fit_transform(y)
y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [ True, False],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True]])

# %%
y.shape
# Out:
# (351, 2)

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,
                                                test_size=0.2,
                                                random_state=24,
                                                stratify=y,
                                                shuffle=True)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((280, 34), (71, 34), (280, 2), (71, 2))

# %%
type(X_train),type(y_train)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
knl_reg = tf.keras.regularizers.L2(l2=0.001)

model = tf.keras.Sequential([
    
    tf.keras.layers.Dense(32,activation='relu',kernel_regularizer = knl_reg),
    tf.keras.layers.Dropout(rate=0.05),
    
    tf.keras.layers.Dense(16,activation='relu',kernel_regularizer = knl_reg),
    tf.keras.layers.Dropout(rate=0.05),
    
    tf.keras.layers.Dense(8,activation='relu',kernel_regularizer = knl_reg),
    tf.keras.layers.Dropout(rate=0.05),
    
    tf.keras.layers.Dense(4,activation='relu',kernel_regularizer = knl_reg),
    tf.keras.layers.Dropout(rate=0.05),
    
    tf.keras.layers.Dense(2,activation='softmax')
    
])

# %%
#ce_loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
ce_loss = tf.keras.losses.CategoricalCrossentropy()

# %%
model.compile(optimizer='adam',loss=ce_loss,metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,
                    validation_data = [X_test,y_test],
                    epochs = 100,
                    batch_size = 32,
                    verbose = 1
                   )
# Out:
# Epoch 1/100
# 9/9 [==============================] - 2s 70ms/step - loss: 0.8069 - accuracy: 0.3571 - val_loss: 0.7443 - val_accuracy: 0.3521
# Epoch 2/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.7273 - accuracy: 0.4143 - val_loss: 0.7016 - val_accuracy: 0.4507
# Epoch 3/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6982 - accuracy: 0.5679 - val_loss: 0.6714 - val_accuracy: 0.7042
# Epoch 4/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6720 - accuracy: 0.7107 - val_loss: 0.6468 - val_accuracy: 0.8169
# Epoch 5/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6464 - accuracy: 0.8286 - val_loss: 0.6251 - val_accuracy: 0.8873
# Epoch 6/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6198 - accuracy: 0.8429 - val_loss: 0.6031 - val_accuracy: 0.8873
# Epoch 7/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5992 - accuracy: 0.8929 - val_loss: 0.5833 - val_accuracy: 0.9014
# Epoch 8/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.5878 - accuracy: 0.8821 - val_loss: 0.5651 - val_accuracy: 0.9014
# Epoch 9/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5702 - accuracy: 0.9000 - val_loss: 0.5479 - val_accuracy: 0.9155
# Epoch 10/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5458 - accuracy: 0.9286 - val_loss: 0.5304 - val_accuracy: 0.9296
# Epoch 11/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5304 - accuracy: 0.9250 - val_loss: 0.5142 - val_accuracy: 0.9437
# Epoch 12/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5094 - accuracy: 0.9357 - val_loss: 0.4976 - val_accuracy: 0.9437
# Epoch 13/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4971 - accuracy: 0.9393 - val_loss: 0.4806 - val_accuracy: 0.9437
# Epoch 14/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4690 - accuracy: 0.9464 - val_loss: 0.4620 - val_accuracy: 0.9437
# Epoch 15/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4459 - accuracy: 0.9571 - val_loss: 0.4412 - val_accuracy: 0.9296
# Epoch 16/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4325 - accuracy: 0.9500 - val_loss: 0.4162 - val_accuracy: 0.9296
# Epoch 17/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4080 - accuracy: 0.9500 - val_loss: 0.3890 - val_accuracy: 0.9437
# Epoch 18/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3893 - accuracy: 0.9429 - val_loss: 0.3633 - val_accuracy: 0.9296
# Epoch 19/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3497 - accuracy: 0.9464 - val_loss: 0.3387 - val_accuracy: 0.9155
# Epoch 20/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3271 - accuracy: 0.9429 - val_loss: 0.3201 - val_accuracy: 0.9296
# Epoch 21/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2878 - accuracy: 0.9500 - val_loss: 0.2982 - val_accuracy: 0.9296
# Epoch 22/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2794 - accuracy: 0.9500 - val_loss: 0.2767 - val_accuracy: 0.9155
# Epoch 23/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2461 - accuracy: 0.9643 - val_loss: 0.2600 - val_accuracy: 0.9437
# Epoch 24/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2424 - accuracy: 0.9571 - val_loss: 0.2438 - val_accuracy: 0.9437
# Epoch 25/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2554 - accuracy: 0.9536 - val_loss: 0.2412 - val_accuracy: 0.9296
# Epoch 26/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2166 - accuracy: 0.9571 - val_loss: 0.2252 - val_accuracy: 0.9577
# Epoch 27/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2073 - accuracy: 0.9536 - val_loss: 0.2276 - val_accuracy: 0.9437
# Epoch 28/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1956 - accuracy: 0.9679 - val_loss: 0.2293 - val_accuracy: 0.9296
# Epoch 29/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1838 - accuracy: 0.9714 - val_loss: 0.2299 - val_accuracy: 0.9296
# Epoch 30/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1775 - accuracy: 0.9714 - val_loss: 0.2142 - val_accuracy: 0.9437
# Epoch 31/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1793 - accuracy: 0.9679 - val_loss: 0.2107 - val_accuracy: 0.9437
# Epoch 32/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1647 - accuracy: 0.9714 - val_loss: 0.2351 - val_accuracy: 0.9296
# Epoch 33/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1710 - accuracy: 0.9714 - val_loss: 0.2173 - val_accuracy: 0.9296
# Epoch 34/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1554 - accuracy: 0.9750 - val_loss: 0.2154 - val_accuracy: 0.9296
# Epoch 35/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1605 - accuracy: 0.9679 - val_loss: 0.2190 - val_accuracy: 0.9437
# Epoch 36/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1464 - accuracy: 0.9786 - val_loss: 0.2223 - val_accuracy: 0.9296
# Epoch 37/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1496 - accuracy: 0.9714 - val_loss: 0.2250 - val_accuracy: 0.9296
# Epoch 38/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1385 - accuracy: 0.9964 - val_loss: 0.2303 - val_accuracy: 0.9296
# Epoch 39/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1337 - accuracy: 0.9821 - val_loss: 0.2321 - val_accuracy: 0.9296
# Epoch 40/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1218 - accuracy: 0.9929 - val_loss: 0.2324 - val_accuracy: 0.9437
# Epoch 41/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1433 - accuracy: 0.9893 - val_loss: 0.2377 - val_accuracy: 0.9296
# Epoch 42/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1393 - accuracy: 0.9750 - val_loss: 0.2346 - val_accuracy: 0.9296
# Epoch 43/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1238 - accuracy: 0.9821 - val_loss: 0.2310 - val_accuracy: 0.9437
# Epoch 44/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1565 - accuracy: 0.9714 - val_loss: 0.2332 - val_accuracy: 0.9296
# Epoch 45/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1250 - accuracy: 0.9929 - val_loss: 0.2568 - val_accuracy: 0.9296
# Epoch 46/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1421 - accuracy: 0.9750 - val_loss: 0.2442 - val_accuracy: 0.9296
# Epoch 47/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1220 - accuracy: 0.9893 - val_loss: 0.2258 - val_accuracy: 0.9296
# Epoch 48/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1231 - accuracy: 0.9857 - val_loss: 0.2168 - val_accuracy: 0.9577
# Epoch 49/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1198 - accuracy: 0.9929 - val_loss: 0.2050 - val_accuracy: 0.9577
# Epoch 50/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1288 - accuracy: 0.9857 - val_loss: 0.2030 - val_accuracy: 0.9577
# Epoch 51/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1347 - accuracy: 0.9786 - val_loss: 0.2014 - val_accuracy: 0.9577
# Epoch 52/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1178 - accuracy: 0.9857 - val_loss: 0.2121 - val_accuracy: 0.9577
# Epoch 53/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1253 - accuracy: 0.9893 - val_loss: 0.2071 - val_accuracy: 0.9437
# Epoch 54/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1227 - accuracy: 0.9857 - val_loss: 0.2091 - val_accuracy: 0.9437
# Epoch 55/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1174 - accuracy: 0.9964 - val_loss: 0.2066 - val_accuracy: 0.9577
# Epoch 56/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1281 - accuracy: 0.9893 - val_loss: 0.2054 - val_accuracy: 0.9577
# Epoch 57/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1162 - accuracy: 0.9893 - val_loss: 0.2134 - val_accuracy: 0.9296
# Epoch 58/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1230 - accuracy: 0.9857 - val_loss: 0.2065 - val_accuracy: 0.9437
# Epoch 59/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1133 - accuracy: 0.9929 - val_loss: 0.1973 - val_accuracy: 0.9577
# Epoch 60/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1120 - accuracy: 0.9929 - val_loss: 0.1959 - val_accuracy: 0.9577
# Epoch 61/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1217 - accuracy: 0.9893 - val_loss: 0.1994 - val_accuracy: 0.9577
# Epoch 62/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1159 - accuracy: 0.9893 - val_loss: 0.2034 - val_accuracy: 0.9577
# Epoch 63/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1189 - accuracy: 0.9964 - val_loss: 0.2031 - val_accuracy: 0.9577
# Epoch 64/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1144 - accuracy: 0.9964 - val_loss: 0.1989 - val_accuracy: 0.9577
# Epoch 65/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1067 - accuracy: 0.9893 - val_loss: 0.1957 - val_accuracy: 0.9577
# Epoch 66/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1261 - accuracy: 0.9893 - val_loss: 0.1807 - val_accuracy: 0.9577
# Epoch 67/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0985 - accuracy: 0.9929 - val_loss: 0.1766 - val_accuracy: 0.9437
# Epoch 68/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1054 - accuracy: 0.9929 - val_loss: 0.1704 - val_accuracy: 0.9718
# Epoch 69/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1053 - accuracy: 0.9929 - val_loss: 0.1680 - val_accuracy: 0.9577
# Epoch 70/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1051 - accuracy: 0.9893 - val_loss: 0.1736 - val_accuracy: 0.9577
# Epoch 71/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1038 - accuracy: 0.9964 - val_loss: 0.1763 - val_accuracy: 0.9577
# Epoch 72/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1016 - accuracy: 0.9929 - val_loss: 0.1813 - val_accuracy: 0.9577
# Epoch 73/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1025 - accuracy: 0.9964 - val_loss: 0.1934 - val_accuracy: 0.9437
# Epoch 74/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0921 - accuracy: 0.9929 - val_loss: 0.2138 - val_accuracy: 0.9155
# Epoch 75/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1131 - accuracy: 0.9929 - val_loss: 0.1934 - val_accuracy: 0.9577
# Epoch 76/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1083 - accuracy: 0.9893 - val_loss: 0.1832 - val_accuracy: 0.9577
# Epoch 77/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0997 - accuracy: 0.9964 - val_loss: 0.1828 - val_accuracy: 0.9577
# Epoch 78/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1015 - accuracy: 0.9929 - val_loss: 0.1870 - val_accuracy: 0.9577
# Epoch 79/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1067 - accuracy: 0.9893 - val_loss: 0.1877 - val_accuracy: 0.9577
# Epoch 80/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1060 - accuracy: 0.9929 - val_loss: 0.1869 - val_accuracy: 0.9577
# Epoch 81/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1002 - accuracy: 0.9929 - val_loss: 0.1879 - val_accuracy: 0.9577
# Epoch 82/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1044 - accuracy: 0.9893 - val_loss: 0.1882 - val_accuracy: 0.9577
# Epoch 83/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0994 - accuracy: 0.9929 - val_loss: 0.1800 - val_accuracy: 0.9577
# Epoch 84/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1118 - accuracy: 0.9821 - val_loss: 0.1744 - val_accuracy: 0.9577
# Epoch 85/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1035 - accuracy: 0.9929 - val_loss: 0.1732 - val_accuracy: 0.9577
# Epoch 86/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1078 - accuracy: 0.9929 - val_loss: 0.1701 - val_accuracy: 0.9577
# Epoch 87/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1070 - accuracy: 0.9929 - val_loss: 0.1674 - val_accuracy: 0.9577
# Epoch 88/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0878 - accuracy: 0.9964 - val_loss: 0.1691 - val_accuracy: 0.9577
# Epoch 89/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1025 - accuracy: 0.9929 - val_loss: 0.1721 - val_accuracy: 0.9577
# Epoch 90/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1139 - accuracy: 0.9893 - val_loss: 0.1772 - val_accuracy: 0.9577
# Epoch 91/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1114 - accuracy: 0.9929 - val_loss: 0.1901 - val_accuracy: 0.9577
# Epoch 92/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1025 - accuracy: 0.9929 - val_loss: 0.1994 - val_accuracy: 0.9577
# Epoch 93/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0990 - accuracy: 0.9929 - val_loss: 0.2037 - val_accuracy: 0.9437
# Epoch 94/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0959 - accuracy: 0.9964 - val_loss: 0.2060 - val_accuracy: 0.9437
# Epoch 95/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1013 - accuracy: 0.9893 - val_loss: 0.2103 - val_accuracy: 0.9437
# Epoch 96/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0849 - accuracy: 0.9964 - val_loss: 0.2191 - val_accuracy: 0.9437
# Epoch 97/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1038 - accuracy: 0.9929 - val_loss: 0.2150 - val_accuracy: 0.9437
# Epoch 98/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0949 - accuracy: 0.9964 - val_loss: 0.2066 - val_accuracy: 0.9437
# Epoch 99/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0914 - accuracy: 0.9964 - val_loss: 0.1979 - val_accuracy: 0.9437
# Epoch 100/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0907 - accuracy: 0.9929 - val_loss: 0.1933 - val_accuracy: 0.9437

# %%
loss_df = pd.DataFrame(history.history)

# %%
fig, axes = plt.subplots(1,2 , figsize = (15,6))

l_range = 50

ax = axes[0]


ax = axes[0]
y1 = loss_df.columns[0]
y2 = loss_df.columns[2]

loss_df.plot(y = [y1,y2], ax = ax)

# little beautification
txtstr = "Errors: \n  Start : {:7.4f}\n   End : {:7.4f}".format(loss_df.iloc[0][y1],
                                                                loss_df.iloc[-1][y2]) #text to plot

# properties  matplotlib.patch.Patch
props = dict(boxstyle='round', facecolor='aqua', alpha=0.5)

# place a text box in upper left in axes coords

ax.text(0.6, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.set_xlabel("Epochs")
ax.set_ylabel("Error")
ax.set_title('Overall')
ax.grid();


y1 = loss_df.columns[1]
y2 = loss_df.columns[3]

ax = axes[1]

loss_df.plot(y = [y1,y2], ax = ax)

# little beautification
txtstr = "Errors: \n  Start : {:7.4f}\n   End : {:7.4f}".format(loss_df.iloc[0][y1],
                                                                loss_df.iloc[-1][y2]) #text to plot

# place a text box in upper left in axes coords

ax.text(0.6, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.set_xlabel("Epochs")
ax.set_ylabel("Error")
ax.set_title('Last {} records'.format(l_range))
ax.grid();
plt.tight_layout()
