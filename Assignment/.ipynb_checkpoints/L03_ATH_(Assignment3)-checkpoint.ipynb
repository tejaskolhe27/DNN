# %% [markdown]
# ## Assignment 3

# %% [markdown]
# - **Name** - Atharva Neelesh Tejale
# - **PRN** - 230940128007

# %% [markdown]
# ## 1. Import Statements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay,classification_report

# %matplotlib inline

# %% [markdown]
# ## 2. Setup Global Parameters

# %%
###----------------
### Some parameters
###----------------

# Directory locations
inpDir = '../../input'
outDir = '../output'

RANDOM_STATE = 23 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

NOISE = 0.2
EPOCHS = 50000  # number of epochs
ALPHA = 0.1  # learning rate
N_SAMPLES = 1000
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## 3. Generate Data Set
# <div style="font-family: Arial; font-size:1.2em;color:white;">
# Sklearn's dataset generator is good source of data for learning. To keep the example simple, I'll suggest  <a href="http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html">make_moon</a> dataset generator.
# </div>

# %%
X,y = datasets.make_moons(n_samples=N_SAMPLES,shuffle=True,noise=NOISE,random_state=RANDOM_STATE)
X.shape,y.shape
# Out:
# ((1000, 2), (1000,))

# %% [markdown]
# ## 4. Visualization
# <p style="font-family: Arial; font-size:1.2em;color:white;">
# DataFrames are easier to visualize
# </p>

# %%
data_df=pd.DataFrame(X,columns=['A','B'])
data_df['target']=y
data_df.head()
# Out:
#           A         B  target
# 0 -0.029033  0.253046       1
# 1  1.288946 -0.079415       1
# 2  0.155971  0.879749       0
# 3  0.032590  0.487471       1
# 4  2.285296  0.462694       1

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   target  1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
data_df.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# A       1000.0  0.491922  0.889694 -1.434693 -0.109430  0.460027  1.094022
# B       1000.0  0.248078  0.540661 -0.919273 -0.215778  0.259477  0.687156
# target  1000.0  0.500000  0.500250  0.000000  0.000000  0.500000  1.000000
#
#              max
# A       2.643058
# B       1.443934
# target  1.000000

# %%
data_df['target'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### 4.1 Different ways of plotting data

# %%
data_df.plot.scatter('A','B',s=10,c='target',cmap=CMAP)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
data_df['target'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.scatterplot(x='A',y='B',data=data_df,hue='target');

# %% [markdown]
# <div style="font-family: Arial; font-size:1.2em;">
#     We will keep 10%, i.e. 100 records for testing and remaining records will be used in training. Note that the data is already random.
# </div>

# %%
y = pd.get_dummies(y).to_numpy()
y.shape
# Out:
# (1000, 2)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=TEST_SIZE,
                                                 stratify=y,random_state=RANDOM_STATE)

X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((800, 2), (200, 2), (800, 2), (200, 2))

# %% [markdown]
# # Over to Perceptron

# %% [markdown]
# <div style="font-family: Arial; font-size:1.1em;">
#
# Our output is binary. To keep the code in line with what we discussed in the lecture, we will simply output 1 for positive values of 'z' and zero for negative values.
# </div>
#
#
# $$
# \begin{aligned}
# z & = 1.0 \circ w_0 + x_1 \circ w_1 + x_2 \circ w_2 \\
# \mathrm{or}\\
# z & = X\circ W \\
# \end{aligned}
# $$
# <br/>
#
#
# $$
# \begin{equation*}
#     \hat{y} = \begin{cases}
#       1.0, & \text{for z>=0}\  \\
#       0.0, & \text{for z<0}\
#     \end{cases}
# \end{equation*}
# $$

# %% [markdown]
# <div style="font-family: Arial; font-size:1em;">
# <p>
# As we know that adjustments in the weights are (a-$\hat{y}$). We don't want to adjust by full value. It makes convergence easier if we adjust by a small fraction. </p>
#     <p><b>Why?</b> We would know better all through this module. We will circle back to learning_rate after some sessions.
# <p>Let's assume that adjusting weights by $\alpha$ * ( a - $\hat{y}$ ) makes better sense. </p>
# <p>
#     <strong>Note:</strong> Take learning_rate ($\alpha$) as some constant.
# </p>
# </div>

# %% [markdown]
# ### Softmax Function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def fn_softmax(z):
    exp_scores = np.exp(z)
    return exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

# %%
fn_softmax(np.array([[-np.inf, 0, np.inf],[-5,2,5]])).sum(axis = 1)
# Out:
# <ipython-input-13-02683e3a40c4>:3: RuntimeWarning: invalid value encountered in divide
#   return exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
# array([nan,  1.])

# %% [markdown]
# ### Tanh Activation Function

# %% [markdown]
# ![tanh.png](data:image/png;base64,...)

# %%
def fn_actv(z):
    return np.tanh(z)
def fn_actv_prime(a):
    return 1- np.tanh(a)**2

# %%
fn_actv(np.array([[-1,0,1],[-np.inf,0,np.inf]]))
# Out:
# array([[-0.76159416,  0.        ,  0.76159416],
#        [-1.        ,  0.        ,  1.        ]])

# %%
np.tanh(0.5)
# Out:
# 0.46211715726000974

# %%
fn_actv_prime(0.5)
# Out:
# 0.7864477329659274

# %% [markdown]
# ## 5. Prediction

# %%
# a function to make prediction
def predict(model,X):
    W1,b1,W2,b2,W3,b3,W4,b4,W5,b5 = model['W1'],model['b1'],model['W2'],model['b2'],model['W3'],model['b3'],model['W4'],model['b4'],model['W5'],model['b5']

    #### Forward Propagation
    ## Layer 1
    z1=X.dot(W1)+b1  #Aggregation Fn
    a1=fn_actv(z1)   #Activation Fn

    ## Layer 2
    z2=a1.dot(W2)+b2  #Aggregation Fn
    a2=fn_actv(z2)    #Activation Fn

    ## Layer 3
    z3 = a2.dot(W3) + b3
    a3 = fn_actv(z3)

    ## Layer 4
    z4 = a3.dot(W4) + b4
    a4 = fn_actv(z4)

    ## Layer 5
    z5 = a4.dot(W5) + b5
    a5 = fn_softmax(z5)

    return np.argmax(a5, axis = 1)

# %% [markdown]
# **Its advisable to test the function**

# %%
def calculate_loss(model,X,y):
    W1,b1,W2,b2,W3,b3,W4,b4,W5,b5 = model['W1'],model['b1'],model['W2'],model['b2'],model['W3'],model['b3'],model['W4'],model['b4'],model['W5'],model['b5']
    m=X.shape[0]
    #### Forward Propagation
    ## Layer 1
    z1=X.dot(W1)+b1  #Aggregation Fn
    a1=fn_actv(z1)   #Activation Fn

    ## Layer 2
    z2=a1.dot(W2)+b2  #Aggregation Fn
    a2=fn_actv(z2)    #Activation Fn

    ## Layer 3
    z3 = a2.dot(W3) + b3
    a3 = fn_actv(z3)

    ## Layer 4
    z4 = a3.dot(W4) + b4
    a4 = fn_actv(z4)

    ## Layer 5
    z5 = a4.dot(W5) + b5
    a5 = fn_softmax(z5)

    data_loss=-(y*np.log(a5)+(1-y)*np.log(1-a5)).sum()

    return 1./m * data_loss

# %% [markdown]
# <div style="font-family: Arial; font-size:1.2em;">
#     <h3>Back-propagation - Estimate Perceptron weights </h3>
#     $
# \begin{aligned}
# \partial{z}  & = a - y \\
# \partial{b}  & = \partial{z} \\
# \partial{w_1}  & = x_1 \circ \partial{z}\\
# \partial{w_2}  & = x_2 \circ \partial{z}\\
# \end{aligned}
# $
#     <hr>
#       $
# \begin{aligned}
# b & = b -  \frac{1}{m} (\alpha \circ \partial{b}) \\
# w_1  & = w_1 - \frac{1}{m}(\alpha \circ \partial{w_1} )\\
# w_2  & = w_2 - \frac{1}{m}(\alpha \circ \partial{w_2} )\\
# \end{aligned}
# $
#     </div>

# %% [markdown]
#  ## 6. Training

# %%
# function to train the model
def build_model(X,y,alpha=ALPHA,epochs=EPOCHS):

    W1 = np.random.rand(nn_input_dim,nn_hdim)/np.sqrt(nn_input_dim)
    W2 = np.random.rand(nn_hdim,nn_hdim2)/np.sqrt(nn_hdim)
    W3 = np.random.rand(nn_hdim2,nn_hdim3)/np.sqrt(nn_hdim2)
    W4 = np.random.rand(nn_hdim3,nn_hdim4)/np.sqrt(nn_hdim3)
    W5 = np.random.rand(nn_hdim4, nn_output_dim) / np.sqrt(nn_hdim4)

    b1 = np.zeros((1,nn_hdim))
    b2 = np.zeros((1,nn_hdim2))
    b3 = np.zeros((1,nn_hdim3))
    b4 = np.zeros((1,nn_hdim4))
    b5 = np.zeros((1, nn_output_dim))

    curr_loss=0
    loss,epoch=[],[]

    m=X.shape[0]

    for i in range(epochs):

        #### Forward Propagation

        ## Layer 1
        z1=X.dot(W1)+b1  #Aggregation Fn
        a1=fn_actv(z1)   #Activation Fn

        ## Layer 2
        z2=a1.dot(W2)+b2  #Aggregation Fn
        a2=fn_actv(z2)    #Activation Fn

        ## Layer 3
        z3 = a2.dot(W3) + b3
        a3 = fn_actv(z3)

        ## Layer 4
        z4 = a3.dot(W4) + b4
        a4 = fn_actv(z4)

        ## Layer 5
        z5 = a4.dot(W5) + b5
        a5 = fn_softmax(z5)

        #### Back Propagation
        dz5 = a5 - y

        ## Layer 5
        assert(z5.shape==dz5.shape),f'error z5 {z5.shape}/{dz5.shape}'
        dW5 = a4.T.dot(dz5)
        assert(W5.shape==dW5.shape),f'error w5 {W5.shape}/{dW5.shape}'
        db5 = np.sum(dz5, axis=0, keepdims=True)
        assert(b5.shape==db5.shape),f'error b5 {b5.shape}/{db5.shape}'
        da4 = dz5.dot(W5.T)

        ## Layer 4
        dz4 = da4 * fn_actv_prime(z4)
        assert(z4.shape==dz4.shape),f'error z4 {z4.shape}/{dz4.shape}'
        dW4 = a3.T.dot(dz4)
        assert(W4.shape==dW4.shape),f'error W4 {W4.shape}/{dW4.shape}'
        db4 = np.sum(dz4, axis=0, keepdims=True)
        assert(b4.shape==db4.shape),f'error b4 {b4.shape}/{db4.shape}'
        da3 = dz4.dot(W4.T)

        ## Layer 3
        dz3 = da3 * fn_actv_prime(z3)
        assert(z3.shape==dz3.shape),f'error z3 {z3.shape}/{dz3.shape}'
        dW3 = a2.T.dot(dz3)
        assert(W3.shape==dW3.shape),f'error W3 {W3.shape}/{dW3.shape}'
        db3 = np.sum(dz3, axis=0, keepdims=True)
        assert(b3.shape==db3.shape),f'error b3 {b3.shape}/{db3.shape}'
        da2 = dz3.dot(W3.T)

        ## Layer 2
        dz2 = da2 * fn_actv_prime(z2)
        assert(z2.shape==dz2.shape),f'error z2 {z2.shape}/{dz2.shape}'
        dW2 = a1.T.dot(dz2)
        assert(W2.shape==dW2.shape),f'error W2 {W2.shape}/{dW2.shape}'
        db2 = np.sum(dz2, axis=0, keepdims=True)
        assert(b2.shape==db2.shape),f'error b2 {b2.shape}/{db2.shape}'
        da1 = dz2.dot(W2.T)

        ## Layer 1
        dz1 = da1 * fn_actv_prime(z1)
        dW1 = X.T.dot(dz1)
        assert(W1.shape==dW1.shape),f'error W1 {W1.shape}/{dW1.shape}'
        db1 = np.sum(dz1, axis=0, keepdims=True)
        assert(b1.shape==db1.shape),f'error b1 {b1.shape}/{db1.shape}'

        # Gradient update
        W1 -= alpha * dW1 / m
        W2 -= alpha * dW2 / m
        W3 -= alpha * dW3 / m
        W4 -= alpha * dW4 / m
        W5 -= alpha * dW5 / m
        b1 -= alpha * db1 / m
        b2 -= alpha * db2 / m
        b3 -= alpha * db3 / m
        b4 -= alpha * db4 / m
        b5 -= alpha * db5 / m

        model = {'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2, 'W3': W3, 'b3': b3,
                 'W4': W4, 'b4': b4, 'W5': W5, 'b5': b5}

        if i % 100 == 0:
            curr_loss = calculate_loss(model, X, y)
            loss.append(curr_loss)
            epoch.append(i)
            print(f'epoch:{i}; current_loss={curr_loss:.4f}')


    hist['loss']=loss
    hist['epoch']=epoch

    return model

# %%
nn_input_dim = X_train.shape[1]
nn_hdim = 50
nn_hdim2 = 50
nn_hdim3 = 40
nn_hdim4 = 30
nn_output_dim = 2

hist = {}

# %%
#y_train = y_train.reshape(-1,1)

# %%
model = build_model(X_train,y_train)
# Out:
# epoch:0; current_loss=1.3701
# epoch:100; current_loss=1.2946
# epoch:200; current_loss=1.2217
# epoch:300; current_loss=1.1601
# epoch:400; current_loss=1.1178
# epoch:500; current_loss=1.0451
# epoch:600; current_loss=1.0182
# epoch:700; current_loss=0.9952
# epoch:800; current_loss=0.9655
# epoch:900; current_loss=0.9352
# epoch:1000; current_loss=0.8975
# epoch:1100; current_loss=0.7917
# epoch:1200; current_loss=0.7074
# epoch:1300; current_loss=0.6486
# epoch:1400; current_loss=0.6172
# epoch:1500; current_loss=0.6009
# epoch:1600; current_loss=0.5915
# epoch:1700; current_loss=0.5848
# epoch:1800; current_loss=0.5790
# epoch:1900; current_loss=0.5720
# epoch:2000; current_loss=0.5545
# epoch:2100; current_loss=0.4839
# epoch:2200; current_loss=0.3463
# epoch:2300; current_loss=0.2245
# epoch:2400; current_loss=0.1701
# epoch:2500; current_loss=0.3257
# epoch:2600; current_loss=0.1662
# epoch:2700; current_loss=0.1541
# epoch:2800; current_loss=0.1482
# epoch:2900; current_loss=0.1445
# epoch:3000; current_loss=0.1421
# epoch:3100; current_loss=0.1406
# epoch:3200; current_loss=0.1395
# epoch:3300; current_loss=0.1388
# epoch:3400; current_loss=0.1382
# epoch:3500; current_loss=0.1378
# epoch:3600; current_loss=0.1374
# epoch:3700; current_loss=0.1371
# epoch:3800; current_loss=0.1368
# epoch:3900; current_loss=0.1366
# epoch:4000; current_loss=0.1364
# epoch:4100; current_loss=0.1362
# epoch:4200; current_loss=0.1360
# epoch:4300; current_loss=0.1358
# epoch:4400; current_loss=0.1357
# epoch:4500; current_loss=0.1355
# epoch:4600; current_loss=0.1354
# epoch:4700; current_loss=0.1352
# epoch:4800; current_loss=0.1351
# epoch:4900; current_loss=0.1349
# epoch:5000; current_loss=0.1348
# epoch:5100; current_loss=0.1347
# epoch:5200; current_loss=0.1346
# epoch:5300; current_loss=0.1344
# epoch:5400; current_loss=0.1343
# epoch:5500; current_loss=0.1342
# epoch:5600; current_loss=0.1341
# epoch:5700; current_loss=0.1340
# epoch:5800; current_loss=0.1339
# epoch:5900; current_loss=0.1337
# epoch:6000; current_loss=0.1336
# epoch:6100; current_loss=0.1335
# epoch:6200; current_loss=0.1334
# epoch:6300; current_loss=0.1333
# epoch:6400; current_loss=0.1332
# epoch:6500; current_loss=0.1331
# epoch:6600; current_loss=0.1330
# epoch:6700; current_loss=0.1329
# epoch:6800; current_loss=0.1327
# epoch:6900; current_loss=0.1326
# epoch:7000; current_loss=0.1325
# epoch:7100; current_loss=0.1324
# epoch:7200; current_loss=0.1323
# epoch:7300; current_loss=0.1322
# epoch:7400; current_loss=0.1321
# epoch:7500; current_loss=0.1320
# epoch:7600; current_loss=0.1318
# epoch:7700; current_loss=0.1317
# epoch:7800; current_loss=0.1316
# epoch:7900; current_loss=0.1315
# epoch:8000; current_loss=0.1314
# epoch:8100; current_loss=0.1313
# epoch:8200; current_loss=0.1312
# epoch:8300; current_loss=0.1311
# epoch:8400; current_loss=0.1309
# epoch:8500; current_loss=0.1308
# epoch:8600; current_loss=0.1307
# epoch:8700; current_loss=0.1306
# epoch:8800; current_loss=0.1305
# epoch:8900; current_loss=0.1304
# epoch:9000; current_loss=0.1303
# epoch:9100; current_loss=0.1302
# epoch:9200; current_loss=0.1301
# epoch:9300; current_loss=0.1300
# epoch:9400; current_loss=0.1299
# epoch:9500; current_loss=0.1297
# epoch:9600; current_loss=0.1296
# epoch:9700; current_loss=0.1295
# epoch:9800; current_loss=0.1294
# epoch:9900; current_loss=0.1293
# epoch:10000; current_loss=0.1292
# epoch:10100; current_loss=0.1291
# epoch:10200; current_loss=0.1290
# epoch:10300; current_loss=0.1289
# epoch:10400; current_loss=0.1288
# epoch:10500; current_loss=0.1287
# epoch:10600; current_loss=0.1286
# epoch:10700; current_loss=0.1285
# epoch:10800; current_loss=0.1283
# epoch:10900; current_loss=0.1282
# epoch:11000; current_loss=0.1281
# epoch:11100; current_loss=0.1280
# epoch:11200; current_loss=0.1279
# epoch:11300; current_loss=0.1278
# epoch:11400; current_loss=0.1277
# epoch:11500; current_loss=0.1276
# epoch:11600; current_loss=0.1275
# epoch:11700; current_loss=0.1274
# epoch:11800; current_loss=0.1273
# epoch:11900; current_loss=0.1272
# epoch:12000; current_loss=0.1271
# epoch:12100; current_loss=0.1270
# epoch:12200; current_loss=0.1269
# epoch:12300; current_loss=0.1268
# epoch:12400; current_loss=0.1267
# epoch:12500; current_loss=0.1266
# epoch:12600; current_loss=0.1265
# epoch:12700; current_loss=0.1264
# epoch:12800; current_loss=0.1263
# epoch:12900; current_loss=0.1262
# epoch:13000; current_loss=0.1261
# epoch:13100; current_loss=0.1260
# epoch:13200; current_loss=0.1260
# epoch:13300; current_loss=0.1259
# epoch:13400; current_loss=0.1258
# epoch:13500; current_loss=0.1257
# epoch:13600; current_loss=0.1256
# epoch:13700; current_loss=0.1255
# epoch:13800; current_loss=0.1254
# epoch:13900; current_loss=0.1254
# epoch:14000; current_loss=0.1253
# epoch:14100; current_loss=0.1252
# epoch:14200; current_loss=0.1251
# epoch:14300; current_loss=0.1251
# epoch:14400; current_loss=0.1250
# epoch:14500; current_loss=0.1249
# epoch:14600; current_loss=0.1248
# epoch:14700; current_loss=0.1248
# epoch:14800; current_loss=0.1247
# epoch:14900; current_loss=0.1246
# epoch:15000; current_loss=0.1245
# epoch:15100; current_loss=0.1245
# epoch:15200; current_loss=0.1244
# epoch:15300; current_loss=0.1243
# epoch:15400; current_loss=0.1243
# epoch:15500; current_loss=0.1242
# epoch:15600; current_loss=0.1242
# epoch:15700; current_loss=0.1241
# epoch:15800; current_loss=0.1240
# epoch:15900; current_loss=0.1240
# epoch:16000; current_loss=0.1239
# epoch:16100; current_loss=0.1238
# epoch:16200; current_loss=0.1238
# epoch:16300; current_loss=0.1237
# epoch:16400; current_loss=0.1237
# epoch:16500; current_loss=0.1236
# epoch:16600; current_loss=0.1235
# epoch:16700; current_loss=0.1235
# epoch:16800; current_loss=0.1234
# epoch:16900; current_loss=0.1234
# epoch:17000; current_loss=0.1233
# epoch:17100; current_loss=0.1233
# epoch:17200; current_loss=0.1232
# epoch:17300; current_loss=0.1231
# epoch:17400; current_loss=0.1231
# epoch:17500; current_loss=0.1230
# epoch:17600; current_loss=0.1230
# epoch:17700; current_loss=0.1229
# epoch:17800; current_loss=0.1229
# epoch:17900; current_loss=0.1228
# epoch:18000; current_loss=0.1227
# epoch:18100; current_loss=0.1227
# epoch:18200; current_loss=0.1226
# epoch:18300; current_loss=0.1226
# epoch:18400; current_loss=0.1225
# epoch:18500; current_loss=0.1225
# epoch:18600; current_loss=0.1224
# epoch:18700; current_loss=0.1224
# epoch:18800; current_loss=0.1223
# epoch:18900; current_loss=0.1222
# epoch:19000; current_loss=0.1222
# epoch:19100; current_loss=0.1221
# epoch:19200; current_loss=0.1221
# epoch:19300; current_loss=0.1220
# epoch:19400; current_loss=0.1220
# epoch:19500; current_loss=0.1219
# epoch:19600; current_loss=0.1218
# epoch:19700; current_loss=0.1218
# epoch:19800; current_loss=0.1217
# epoch:19900; current_loss=0.1217
# epoch:20000; current_loss=0.1216
# epoch:20100; current_loss=0.1216
# epoch:20200; current_loss=0.1215
# epoch:20300; current_loss=0.1214
# epoch:20400; current_loss=0.1214
# epoch:20500; current_loss=0.1213
# epoch:20600; current_loss=0.1213
# epoch:20700; current_loss=0.1212
# epoch:20800; current_loss=0.1211
# epoch:20900; current_loss=0.1211
# epoch:21000; current_loss=0.1210
# epoch:21100; current_loss=0.1210
# epoch:21200; current_loss=0.1209
# epoch:21300; current_loss=0.1208
# epoch:21400; current_loss=0.1208
# epoch:21500; current_loss=0.1207
# epoch:21600; current_loss=0.1206
# epoch:21700; current_loss=0.1206
# epoch:21800; current_loss=0.1205
# epoch:21900; current_loss=0.1205
# epoch:22000; current_loss=0.1204
# epoch:22100; current_loss=0.1203
# epoch:22200; current_loss=0.1203
# epoch:22300; current_loss=0.1202
# epoch:22400; current_loss=0.1201
# epoch:22500; current_loss=0.1201
# epoch:22600; current_loss=0.1200
# epoch:22700; current_loss=0.1199
# epoch:22800; current_loss=0.1198
# epoch:22900; current_loss=0.1198
# epoch:23000; current_loss=0.1197
# epoch:23100; current_loss=0.1196
# epoch:23200; current_loss=0.1196
# epoch:23300; current_loss=0.1195
# epoch:23400; current_loss=0.1194
# epoch:23500; current_loss=0.1193
# epoch:23600; current_loss=0.1193
# epoch:23700; current_loss=0.1192
# epoch:23800; current_loss=0.1191
# epoch:23900; current_loss=0.1190
# epoch:24000; current_loss=0.1190
# epoch:24100; current_loss=0.1189
# epoch:24200; current_loss=0.1188
# epoch:24300; current_loss=0.1187
# epoch:24400; current_loss=0.1186
# epoch:24500; current_loss=0.1186
# epoch:24600; current_loss=0.1185
# epoch:24700; current_loss=0.1184
# epoch:24800; current_loss=0.1183
# epoch:24900; current_loss=0.1182
# epoch:25000; current_loss=0.1181
# epoch:25100; current_loss=0.1180
# epoch:25200; current_loss=0.1180
# epoch:25300; current_loss=0.1179
# epoch:25400; current_loss=0.1178
# epoch:25500; current_loss=0.1177
# epoch:25600; current_loss=0.1176
# epoch:25700; current_loss=0.1175
# epoch:25800; current_loss=0.1174
# epoch:25900; current_loss=0.1173
# epoch:26000; current_loss=0.1172
# epoch:26100; current_loss=0.1171
# epoch:26200; current_loss=0.1170
# epoch:26300; current_loss=0.1169
# epoch:26400; current_loss=0.1168
# epoch:26500; current_loss=0.1166
# epoch:26600; current_loss=0.1165
# epoch:26700; current_loss=0.1164
# epoch:26800; current_loss=0.1163
# epoch:26900; current_loss=0.1162
# epoch:27000; current_loss=0.1160
# epoch:27100; current_loss=0.1159
# epoch:27200; current_loss=0.1158
# epoch:27300; current_loss=0.1157
# epoch:27400; current_loss=0.1155
# epoch:27500; current_loss=0.1154
# epoch:27600; current_loss=0.1153
# epoch:27700; current_loss=0.1151
# epoch:27800; current_loss=0.1150
# epoch:27900; current_loss=0.1148
# epoch:28000; current_loss=0.1147
# epoch:28100; current_loss=0.1145
# epoch:28200; current_loss=0.1144
# epoch:28300; current_loss=0.1142
# epoch:28400; current_loss=0.1141
# epoch:28500; current_loss=0.1139
# epoch:28600; current_loss=0.1138
# epoch:28700; current_loss=0.1136
# epoch:28800; current_loss=0.1134
# epoch:28900; current_loss=0.1132
# epoch:29000; current_loss=0.1131
# epoch:29100; current_loss=0.1129
# epoch:29200; current_loss=0.1127
# epoch:29300; current_loss=0.1125
# epoch:29400; current_loss=0.1123
# epoch:29500; current_loss=0.1121
# epoch:29600; current_loss=0.1118
# epoch:29700; current_loss=0.1116
# epoch:29800; current_loss=0.1114
# epoch:29900; current_loss=0.1111
# epoch:30000; current_loss=0.1109
# epoch:30100; current_loss=0.1106
# epoch:30200; current_loss=0.1104
# epoch:30300; current_loss=0.1101
# epoch:30400; current_loss=0.1112
# epoch:30500; current_loss=0.1109
# epoch:30600; current_loss=0.1106
# epoch:30700; current_loss=0.1103
# epoch:30800; current_loss=0.1101
# epoch:30900; current_loss=0.1098
# epoch:31000; current_loss=0.1095
# epoch:31100; current_loss=0.1092
# epoch:31200; current_loss=0.1089
# epoch:31300; current_loss=0.1086
# epoch:31400; current_loss=0.1083
# epoch:31500; current_loss=0.1080
# epoch:31600; current_loss=0.1077
# epoch:31700; current_loss=0.1074
# epoch:31800; current_loss=0.1071
# epoch:31900; current_loss=0.1068
# epoch:32000; current_loss=0.1064
# epoch:32100; current_loss=0.1061
# epoch:32200; current_loss=0.1058
# epoch:32300; current_loss=0.1055
# epoch:32400; current_loss=0.1051
# epoch:32500; current_loss=0.1048
# epoch:32600; current_loss=0.1045
# epoch:32700; current_loss=0.1041
# epoch:32800; current_loss=0.1038
# epoch:32900; current_loss=0.1035
# epoch:33000; current_loss=0.1031
# epoch:33100; current_loss=0.1028
# epoch:33200; current_loss=0.1025
# epoch:33300; current_loss=0.1022
# epoch:33400; current_loss=0.1019
# epoch:33500; current_loss=0.1016
# epoch:33600; current_loss=0.1013
# epoch:33700; current_loss=0.1010
# epoch:33800; current_loss=0.1007
# epoch:33900; current_loss=0.1005
# epoch:34000; current_loss=0.1002
# epoch:34100; current_loss=0.0999
# epoch:34200; current_loss=0.0997
# epoch:34300; current_loss=0.0994
# epoch:34400; current_loss=0.0991
# epoch:34500; current_loss=0.0989
# epoch:34600; current_loss=0.0986
# epoch:34700; current_loss=0.0983
# epoch:34800; current_loss=0.0981
# epoch:34900; current_loss=0.0978
# epoch:35000; current_loss=0.0975
# epoch:35100; current_loss=0.0972
# epoch:35200; current_loss=0.0969
# epoch:35300; current_loss=0.0967
# epoch:35400; current_loss=0.0964
# epoch:35500; current_loss=0.0961
# epoch:35600; current_loss=0.0958
# epoch:35700; current_loss=0.0955
# epoch:35800; current_loss=0.0952
# epoch:35900; current_loss=0.0949
# epoch:36000; current_loss=0.0946
# epoch:36100; current_loss=0.0942
# epoch:36200; current_loss=0.0939
# epoch:36300; current_loss=0.0936
# epoch:36400; current_loss=0.0933
# epoch:36500; current_loss=0.0930
# epoch:36600; current_loss=0.0926
# epoch:36700; current_loss=0.0923
# epoch:36800; current_loss=0.0920
# epoch:36900; current_loss=0.0916
# epoch:37000; current_loss=0.0913
# epoch:37100; current_loss=0.0909
# epoch:37200; current_loss=0.0906
# epoch:37300; current_loss=0.0902
# epoch:37400; current_loss=0.0899
# epoch:37500; current_loss=0.0895
# epoch:37600; current_loss=0.0892
# epoch:37700; current_loss=0.0888
# epoch:37800; current_loss=0.0885
# epoch:37900; current_loss=0.0882
# epoch:38000; current_loss=0.0901
# epoch:38100; current_loss=0.0891
# epoch:38200; current_loss=0.0885
# epoch:38300; current_loss=0.0880
# epoch:38400; current_loss=0.0876
# epoch:38500; current_loss=0.0872
# epoch:38600; current_loss=0.0868
# epoch:38700; current_loss=0.0864
# epoch:38800; current_loss=0.0861
# epoch:38900; current_loss=0.0857
# epoch:39000; current_loss=0.0854
# epoch:39100; current_loss=0.0850
# epoch:39200; current_loss=0.0847
# epoch:39300; current_loss=0.0843
# epoch:39400; current_loss=0.0839
# epoch:39500; current_loss=0.0836
# epoch:39600; current_loss=0.0832
# epoch:39700; current_loss=0.0829
# epoch:39800; current_loss=0.0825
# epoch:39900; current_loss=0.0822
# epoch:40000; current_loss=0.0818
# epoch:40100; current_loss=0.0814
# epoch:40200; current_loss=0.0811
# epoch:40300; current_loss=0.0807
# epoch:40400; current_loss=0.0804
# epoch:40500; current_loss=0.0800
# epoch:40600; current_loss=0.0797
# epoch:40700; current_loss=0.0793
# epoch:40800; current_loss=0.0789
# epoch:40900; current_loss=0.0786
# epoch:41000; current_loss=0.0782
# epoch:41100; current_loss=0.0779
# epoch:41200; current_loss=0.0775
# epoch:41300; current_loss=0.0772
# epoch:41400; current_loss=0.0768
# epoch:41500; current_loss=0.0765
# epoch:41600; current_loss=0.0761
# epoch:41700; current_loss=0.0758
# epoch:41800; current_loss=0.0754
# epoch:41900; current_loss=0.0751
# epoch:42000; current_loss=0.0747
# epoch:42100; current_loss=0.0749
# epoch:42200; current_loss=0.0746
# epoch:42300; current_loss=0.0743
# epoch:42400; current_loss=0.0740
# epoch:42500; current_loss=0.0737
# epoch:42600; current_loss=0.0733
# epoch:42700; current_loss=0.0730
# epoch:42800; current_loss=0.0726
# epoch:42900; current_loss=0.0723
# epoch:43000; current_loss=0.0720
# epoch:43100; current_loss=0.0716
# epoch:43200; current_loss=0.0713
# epoch:43300; current_loss=0.0710
# epoch:43400; current_loss=0.0706
# epoch:43500; current_loss=0.0703
# epoch:43600; current_loss=0.0700
# epoch:43700; current_loss=0.0697
# epoch:43800; current_loss=0.0694
# epoch:43900; current_loss=0.0691
# epoch:44000; current_loss=0.0688
# epoch:44100; current_loss=0.0685
# epoch:44200; current_loss=0.0682
# epoch:44300; current_loss=0.0679
# epoch:44400; current_loss=0.0677
# epoch:44500; current_loss=0.0674
# epoch:44600; current_loss=0.0671
# epoch:44700; current_loss=0.0669
# epoch:44800; current_loss=0.0666
# epoch:44900; current_loss=0.0664
# epoch:45000; current_loss=0.0661
# epoch:45100; current_loss=0.0659
# epoch:45200; current_loss=0.0656
# epoch:45300; current_loss=0.0654
# epoch:45400; current_loss=0.0652
# epoch:45500; current_loss=0.0649
# epoch:45600; current_loss=0.0647
# epoch:45700; current_loss=0.0639
# epoch:45800; current_loss=0.0629
# epoch:45900; current_loss=0.0631
# epoch:46000; current_loss=0.0622
# epoch:46100; current_loss=0.0620
# epoch:46200; current_loss=0.0618
# epoch:46300; current_loss=0.0617
# epoch:46400; current_loss=0.0615
# epoch:46500; current_loss=0.0614
# epoch:46600; current_loss=0.0613
# epoch:46700; current_loss=0.0673
# epoch:46800; current_loss=0.0661
# epoch:46900; current_loss=0.0653
# epoch:47000; current_loss=0.0646
# epoch:47100; current_loss=0.0641
# epoch:47200; current_loss=0.0635
# epoch:47300; current_loss=0.0600
# epoch:47400; current_loss=0.0599
# epoch:47500; current_loss=0.0597
# epoch:47600; current_loss=0.0596
# epoch:47700; current_loss=0.0594
# epoch:47800; current_loss=0.0593
# epoch:47900; current_loss=0.0591
# epoch:48000; current_loss=0.0590
# epoch:48100; current_loss=0.0588
# epoch:48200; current_loss=0.0587
# epoch:48300; current_loss=0.0586
# epoch:48400; current_loss=0.0584
# epoch:48500; current_loss=0.0583
# epoch:48600; current_loss=0.0582
# epoch:48700; current_loss=0.0581
# epoch:48800; current_loss=0.0579
# epoch:48900; current_loss=0.0578
# epoch:49000; current_loss=0.0577
# epoch:49100; current_loss=0.0578
# epoch:49200; current_loss=0.0574
# epoch:49300; current_loss=0.0572
# epoch:49400; current_loss=0.0582
# epoch:49500; current_loss=0.0574
# epoch:49600; current_loss=0.0569
# epoch:49700; current_loss=0.0568
# epoch:49800; current_loss=0.0561
# epoch:49900; current_loss=0.0529

# %%
pd.DataFrame(hist).plot(x = 'epoch')
# Out:
# <Axes: xlabel='epoch'>

# %% [markdown]
# ## 7. Predictions
#
# ### Train Set

# %%
y_pred = predict(model, X_train)
y_pred.shape
# Out:
# (800,)

# %%
print('Accuracy score on Train Data :', accuracy_score(np.argmax(y_train, axis = 1), y_pred))
# Out:
# Accuracy score on Train Data : 0.99

# %%
print(classification_report(np.argmax(y_train,axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       400
#            1       0.99      0.99      0.99       400
#
#     accuracy                           0.99       800
#    macro avg       0.99      0.99      0.99       800
# weighted avg       0.99      0.99      0.99       800

# %% [markdown]
# #### Confusion Matrix for Train set

# %%
cm  = confusion_matrix(np.argmax(y_train,axis=1), y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              #display_labels=labels.values()
                             )

fig, ax = plt.subplots(figsize = (4,4))

disp.plot(ax = ax, cmap = 'Blues', colorbar=False)

plt.show();

# %% [markdown]
# ### Test Set

# %%
y_pred = predict(model, X_test)

print('Accuracy score on Test Data :', accuracy_score(np.argmax(y_test,axis=1), y_pred))
# Out:
# Accuracy score on Test Data : 0.955

# %%
print(classification_report(np.argmax(y_test,axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       100
#            1       0.95      0.96      0.96       100
#
#     accuracy                           0.95       200
#    macro avg       0.96      0.95      0.95       200
# weighted avg       0.96      0.95      0.95       200

# %% [markdown]
# #### Confusion Matrix for Test Set

# %%
cm  = confusion_matrix(np.argmax(y_test,axis=1), y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              #display_labels=labels.values()
                             )

fig, ax = plt.subplots(figsize = (4,4))

disp.plot(ax = ax, cmap = 'Blues', colorbar=False)

plt.show();

# %% [markdown]
# ## Decision Boundary

# %%
def fn_plot_decision_boundary(pred_func,X_tr,y_tr,X_ts,y_ts):
    '''
        Attrib:
           pred_func : function based on predict method of the classifier
           X_tr : train feature matrix
           y_tr : train labels
           X_ts : test feature matrix
           y_ts : test labels
       Return:
           None
    '''

    # Set min and max values and give it some padding
    xMin, xMax = X_tr[:, 0].min() - .05, X_tr[:, 0].max() + .05
    yMin, yMax = X_tr[:, 1].min() - .05, X_tr[:, 1].max() + .05

    # grid size for mesh grid
    h = 0.01

    # Generate a grid of points with distance 'h' between them
    xx, yy = np.meshgrid(np.arange(xMin, xMax, h), np.arange(yMin, yMax, h))

    # Predict the function value for the whole grid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])

    # Make its shape same as that of xx
    Z = Z.reshape(xx.shape)

    fig = plt.figure()
    ax = fig.add_axes(111)

    # Now we have Z value corresponding to each of the combination of xx and yy
    # Plot the contour and training examples
    ax.contourf(xx, yy, Z, cmap=CMAP) #, alpha = 0.8

    # Plotting scatter for train data
    ax.scatter(X_tr[:, 0], X_tr[:, 1], c=np.argmax(y_tr,axis=1),
                                  s=30, edgecolor='k', cmap=plt.cm.coolwarm)


    # Plotting scatter for test data
    ax.scatter(X_ts[:, 0], X_ts[:, 1], c=np.argmax(y_ts,axis=1),
                                  s=150, marker = '*',edgecolor='k', cmap=plt.cm.inferno )

# %%
loss_df = pd.DataFrame(hist)

fn_plot_decision_boundary(lambda x: predict(model, x), X_train, y_train, X_test, y_test) # plot decision boundary for this plot

plt.title("Decision Boundary");

# %% [markdown]
# ## Tracking
# <div style="font-family: Arial; font-size:1.2em;color:black;">
# Lets track the results across various implementations...
#
#  |#|Implementation|Training Accuracy|Testing Accuracy|Remarks|
#  |:-:|---|---|---|---|
#  |1|Simple Perceptron|0.83111|0.89000||

# %% [markdown]
# ## A note on Loss Function
# <div style="font-family: Arial; font-size:1.2em;">
#     <p>In logistic regression we are looking for if it is correct class or not. </p>
#     <p>For example, we want to know if there is a car in the picture or not. So the output is probability of a car in the picture.</p>
#     <p><b>Mathematically speaking:</b></p>
#     <p>$\hat{y} = p(y=1|x)$ i.e. given training sample $x$, we want to know probability of $y$ being 1.</p>
#     <br>
#     <p><b>Alternatively:</b></p>
#     <p>If there is a car in the picture.  $\Rightarrow$  $y$ = 1 then $p(y|x)$ = $\hat{y}$.</p>
#     <p>If there is <b>no</b> car in the picture.$\Rightarrow$ $y$ = 0 then $p(y|x)$ = 1 - $\hat{y}$.</p>
#     <br>
#     <p>We can summarize two equations as: $p(y|x)$ = $\hat{y}^{y} * (1 - \hat{y}) ^{(1-y)}$</p>
#     <p>Above equation is $\hat{y}$ for y = 1 and (1 - $\hat{y}$) for y = 0.</p>
#     <p>Taking log of above equation:</p>
#
# $
# \begin{aligned}
# log [ p(y|x) ] & = log[\hat{y}^{y} * (1 - \hat{y}) ^{(1-y)}]\\
# & = y * log(\hat{y}) + (1-y) * log(1 - \hat{y})\\
# \end{aligned}
# $
# <p>Since we aim to minimize above function, add negative sign and our loss function becomes</p>
#
# $
# \begin{aligned}
# L(\hat{y},y) =  -[y * log\hat{y} + (1-y) * log(1-\hat{y})]\\
# \text{or}\\
# L(a,y) =  - [ y * log ( a ) + ( 1 - y ) * log( 1 - a ) ]\\
# \end{aligned}
# $
#
# |Case| y |Loss| a |-log(a)|-log(1-a)|
# |:-: |:-:|:-: |:-:|  :-: |   :-:  |
# | 1  | 0 | -log( 1 - a )| 0.000001 |13.8155|**1 e-6**|
# | 2  | 0 | -log( 1 - a )| 0.999999 |1 e-6|**13.8155**|
# | 3  | 1 | -log( a )| 0.000001 |**13.8155**|1 e-6|
# | 4  | 1 | -log( a )| 0.999999 |**1 e-6**|13.8155|
#
# </div>

# %% [markdown]
# <div style="font-family: Arial; font-size:1.2em;">
#     <p>For binary classification the error = - $y * log(a)$</p>
#     <p>We want to sum it up for all samples in the dataset. Hence:</p>
#
# $
# \begin{aligned}
# p(\text{all ys | all rows of x}) & =  \Pi_{i=0}^m p(y|x)\\
# log [ p(\text{all ys | all rows of x})] & =  log [ \Pi_{i=0}^m p(y|x) ]\\
# & =  \sum_{i=0}^m log [ p(y|x) ] \\
# & =  \sum_{i=0}^m [ y * log(\hat{y}) + (1-y) * log(1 - \hat{y}) ]\\
# \text{Divide it by m to better scale the costs}\\
# & = \frac{1}{m} * \sum_{i=0}^m [ y * log(\hat{y}) + (1-y) * log(1 - \hat{y}) ]\\
# \end{aligned}
# $

# %% [markdown]
# ### Introducing $\mathrm{sigmoid}$ function for our binary output.
# $$
# \begin{aligned}
# z & = x_1 . w_1 + x_2 . w_2 + b_1 \\
# a & = \hat{y} = \sigma(z)\\
# dz & = (a - y) \\
# db & = dz\\
# b & = b - \alpha . db\\
# dw_1 & = x_1. dz\\
# dw_2 & = x_2.dz\\
# w_1 & = w_1 - \alpha . dw_1\\
# w_2 & = w_1 - \alpha . dw_2\\
# \end{aligned}
# $$
# ### Sigmoid function
# $$
# \begin{align}
# a &= \sigma(z)\\
# &= \dfrac{1}{1 + e^{-z}}\\
# \end{align}
# $$
#     <h3>Derivative of sigmoid function</h3>
# $$
# \begin{align}
# \partial{a} &= \partial{(\sigma(z))}\\
# &= \dfrac{\partial}{\partial{z}} \left[ \dfrac{1}{1 + e^{-z}} \right] \\
# &= \dfrac{\partial}{\partial{z}} \left( 1 + \mathrm{e}^{-z} \right)^{-1} \\
# &= -(1 + e^{-z})^{-2}(-e^{-z}) \\
# &= \dfrac{e^{-z}}{\left(1 + e^{-z}\right)^2} \\
# &= \dfrac{1}{1 + e^{-z}\ } \circ \dfrac{e^{-z}}{1 + e^{-z}}  \\
# &= \dfrac{1}{1 + e^{-z}\ } \circ \dfrac{(1 + e^{-z}) - 1}{1 + e^{-z}}  \\
# &= \dfrac{1}{1 + e^{-z}\ } \circ \left[ \dfrac{1 + e^{-z}}{1 + e^{-z}} - \dfrac{1}{1 + e^{-z}} \right] \\
# &= \dfrac{1}{1 + e^{-z}\ } \circ \left[ 1 - \dfrac{1}{1 + e^{-z}} \right] \\
# &= \sigma(z) \circ (1 - \sigma(z))\\
# &= a \circ (1 - a)
# \end{align}
# $$
#     </div>
